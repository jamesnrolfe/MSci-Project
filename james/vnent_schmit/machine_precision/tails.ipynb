# %%
using JLD2, FileIO
using Plots

data_loc = "simulation_results_mp.jld2"

N_vals = 10:10:80
σ_vals = [0.000, 0.001, 0.002]
# Out:
# 3-element Vector{Float64}:
#  0.0
#  0.001
#  0.002

# %%
function plot_bond_dim_vs_N(N_vals, σ_vals, data_loc)
    
    gr() 
    bond_dim_plot = plot(
        title = "Average Max Bond Dimension vs. System Size",
        xlabel = "System Size (N)",
        ylabel = "Average Max Bond Dimension (χ)",
        legend = :topleft
    )
    
    if !isfile(data_loc)
        println("Error: Results file not found at '$data_loc'")
        println("Please run your 'get_data.jl' simulation script first.")
        return
    end
    

    jldopen(data_loc, "r") do file

        for σ in σ_vals
            plot_N = Float64[]
            plot_chi = Float64[]
            plot_chi_err = Float64[]
            
    
            for N in N_vals
                group_path = "N=$(N)/sigma=$(σ)"
                
        
                if haskey(file, group_path)
        
                    avg_chi = file[group_path]["avg_bond_dim"]
                    err_chi = file[group_path]["err_bond_dim"]
                    
          
                    push!(plot_N, N) 
                    push!(plot_chi, avg_chi)
                    push!(plot_chi_err, err_chi)
                else
                    println("Warning: Missing data for N=$N, σ=$σ. Skipping this point.")
                end
            end
            

            if !isempty(plot_N)
                plot!(
                    bond_dim_plot,
                    plot_N, 
                    plot_chi,
                    yerror = plot_chi_err, 
                    label = "σ = $σ",
                    markersize = 4,
                    capstyle = :round 
                )
            else
                println("No data found for σ = $σ.")
            end
        end
    end
    
    display(bond_dim_plot)

end

plot_bond_dim_vs_N(N_vals, σ_vals, data_loc)
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588

# %%
function plot_schmidt_coefficient_tail_comparison_first_run(N_vals, σ_vals, data_loc)
    """
    Create plots showing Schmidt coefficients sorted by magnitude using the SAME data
    as the entropy contributions plot (first run only).
    """
    
    if !isfile(data_loc)
        println("Error: Results file not found at '$data_loc'")
        return
    end

    gr()
    plot_list = []
    
    jldopen(data_loc, "r") do file
        for N in N_vals
            subplot = plot(
                title = "N = $N",
                xlabel = "Schmidt Index (sorted)",
                ylabel = "Schmidt Coefficient Value (λ)",
                yscale = :log10,
                legend = :topright,
                yaxis = (formatter = :scientific),
            )
            
            for σ in reverse!(σ_vals)
                group_path = "N=$(N)/sigma=$(σ)"
                
                if haskey(file, group_path)
                    all_run_coefs = file[group_path]["schmidt_coefs"]
                    
                    first_run = all_run_coefs[1]
                    
                    if first_run isa Vector{Float64}
                        run_coefs = first_run
                    else
                        run_coefs = first_run.storage.data
                    end
                    
                    spectrum = run_coefs .^ 2
                    # spectrum = spectrum[spectrum .> 1e-15]
                    spectrum ./= sum(spectrum)
                    
                    sorted_indices = sortperm(spectrum, rev=true)
                    sorted_spec = spectrum[sorted_indices]
                    
                    x_vals = 1:length(sorted_spec)
                    
                    plot!(
                        subplot,
                        x_vals,
                        sorted_spec,
                        label = "σ = $σ",
                        linewidth = 2
                    )
                else
                    println("Warning: Missing data for N=$N, σ=$σ")
                end
            end
            
            push!(plot_list, subplot)
        end
    end
    
    final_plot = plot(
        plot_list...,
        layout = (4, 2),
        size = (1400, 1800),
        plot_title = "Schmidt Coefficient Tail Behavior"
    )
    
    display(final_plot)
    savefig(final_plot, "schmidt_coefficient_tails_first_run.png")
    println("Plot saved to schmidt_coefficient_tails_first_run.png")
end

plot_schmidt_coefficient_tail_comparison_first_run(N_vals, σ_vals, data_loc)
# Out:
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# Plot saved to schmidt_coefficient_tails_first_run.png

# %% [markdown]
# Now we want to confirm what the weight of the tail is (i.e. how much does it contribute to the overall VN entropy).
#
# We will do this, by essentially finding the point at which the tail deviates from the $\sigma=0$ case, and summing up all those values. Let's first just see if we can just find that point from which the deviation occurs. We'll write a function to do this for one $N$ and one $\sigma \neq 0$.

# %%
function sorted_spec(N, σ)

    # we need to get the runs for the zero sigma case, and the sigma we entered. 

    if !isfile(data_loc)
        println("Error: results file not found at $data_loc")
        return nothing
    end

    jldopen(data_loc, "r") do file

        # Load σ data
        group_path_σ = "N=$(N)/sigma=$(σ)"
        if !haskey(file, group_path_σ)
            println("Warning: Missing data for N=$N, σ=$σ")
            return nothing
        end
        all_run_coefs_σ = file[group_path_σ]["schmidt_coefs"]
        first_run_σ = all_run_coefs_σ[1]
        if first_run_σ isa Vector{Float64}
            run_coefs_σ = first_run_σ
        else
            run_coefs_σ = first_run_σ.storage.data
        end
        spectrum_σ = run_coefs_σ .^ 2
        # spectrum_σ = spectrum_σ[spectrum_σ .> 1e-15]
        spectrum_σ ./= sum(spectrum_σ)
        sorted_spec_σ = sort(spectrum_σ, rev=true)

        return sorted_spec_σ

    end # end jldopen

end
# Out:
# sorted_spec (generic function with 1 method)

# %%
sorted_spec_0000 = sorted_spec(50, 0.00)
sorted_spec_0001 = sorted_spec(50, 0.001)
sorted_spec_0002 = sorted_spec(50, 0.002)
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# 492-element Vector{Float64}:
#  0.21392592958624593
#  0.2139259295862441
#  0.15717247053859035
#  0.1571724705385896
#  0.08452644299080202
#  0.08452644299079642
#  0.033019654047806095
#  0.033019654047795444
#  0.00925520861155709
#  0.009255208611554102
#  0.0018283288698061914
#  0.0018283288697850486
#  0.00024818924398298817
#  ⋮
#  3.7607862968065194e-17
#  3.760786210873161e-17
#  2.9641759547414484e-17
#  2.961105675071508e-17
#  2.7600421814771014e-17
#  2.757751992608378e-17
#  2.4213614402621422e-17
#  2.370237079807692e-17
#  2.3685058543364174e-17
#  2.133384124250395e-17
#  1.3124781685100149e-17
#  1.3124781667143388e-17

# %%
function find_tail_divergence(clean_spec, disordered_spec; ratio_threshold=5.0, min_val=1e-20)

    for i in 1:min(length(clean_spec), length(disordered_spec))
        val_clean = clean_spec[i]
        val_disordered = disordered_spec[i]
        
        if val_clean < min_val
            if val_disordered > min_val * 10
                return i
            else
                continue 
            end
        end
        ratio = val_disordered / val_clean
        
        if ratio > ratio_threshold
            return i
        end
    end
    
    return length(clean_spec) # Fallback if no deviation found
end

deviation_idx = find_tail_divergence(sorted_spec_0000, sorted_spec_0002, ratio_threshold=5.0)

println("Deviation found at index: $deviation_idx")
# Out:
# Deviation found at index: 21

# %%
function verify_deviation_zoom(clean_spec, disordered_spec, dev_idx; window=15)
    # 1. Define the safe zoom window (clamping to array bounds)
    len = min(length(clean_spec), length(disordered_spec))
    start_idx = max(1, dev_idx - window)
    end_idx = min(len, dev_idx + window)
    
    # The x-axis range
    rng = start_idx:end_idx

    # 2. Base Plot
    p = plot(rng, clean_spec[rng], 
        label="Clean (σ=0)", 
        color=:blue, 
        linestyle=:dash, 
        linewidth=2,
        yscale=:log10,           # Crucial for seeing tails
        marker=:circle,          # distinct points help verify exact indices
        markersize=3,
        title="Zoom around Index $dev_idx",
        xlabel="Schmidt Index",
        ylabel="Eigenvalue (Log Scale)",
        legend=:bottomleft       # Moves legend out of the way of the tail usually
    )

    # 3. Add Disordered Data
    plot!(p, rng, disordered_spec[rng], 
        label="Disordered", 
        color=:red, 
        linewidth=2,
        marker=:diamond,
        markersize=3
    )

    # 4. Highlight the specific cut-off point
    vline!(p, [dev_idx], 
        label="Detected Point", 
        color=:black, 
        linewidth=2,
        linestyle=:dot
    )

    display(p)
end

# 1. Find the index (using the logic from the previous step)
dev_index = find_tail_divergence(sorted_spec_0000, sorted_spec_0002, ratio_threshold=5.0)

# 2. Visual Check
verify_deviation_zoom(sorted_spec_0000, sorted_spec_0002, dev_index, window=20)

# %%
function safe_xlogx(x)
    """handles error when computer tries to do logs with small numbers"""
    if x <= 1e-20
        return 0.0 # xlogx tends to this for small vals anyway
    end
    return x * log(x)
end

function find_body_entropy_contribution(sorted_spec, deivation_idx)
    truncated_sorted_spec = sorted_spec[1 : deviation_idx - 1]
    return sum(safe_xlogx(x) for x in truncated_sorted_spec)
end

function find_tail_entropy_contribution(sorted_spec, deviation_idx)
    truncated_sorted_spec = sorted_spec[deviation_idx : end]
    return sum(safe_xlogx(x) for x in truncated_sorted_spec)
end
# Out:
# find_tail_entropy_contribution (generic function with 1 method)

# %%
# find body and Tail

body_cnt_0000 = find_body_entropy_contribution(sorted_spec_0000, dev_index)
tail_cnt_0000 = find_tail_entropy_contribution(sorted_spec_0000, dev_index)
total_ent_0000 = body_cnt_0000 + tail_cnt_0000
bt_ratio_0000 = body_cnt_0000 / tail_cnt_0000

body_cnt_0002 = find_body_entropy_contribution(sorted_spec_0002, dev_index)
tail_cnt_0002 = find_tail_entropy_contribution(sorted_spec_0002, dev_index)
total_ent_0002 = body_cnt_0002 + tail_cnt_0002
bt_ratio_0002 = body_cnt_0002 / tail_cnt_0002

diff_body = abs(body_cnt_0000 - body_cnt_0002)
diff_tail = abs(tail_cnt_0000 - tail_cnt_0002)
total_err = abs(total_ent_0000 - total_ent_0002)

println("Body contributions: 0.000 -> $body_cnt_0000, 0.002 -> $body_cnt_0002")
println("Tail contributions: 0.000 -> $tail_cnt_0000, 0.002 -> $tail_cnt_0002")
println("BT Ratio: 0.000 -> $bt_ratio_0000, 0.002 -> $bt_ratio_0002")
println("Total contributions: 0.000 -> $total_ent_0000, 0.002 -> $total_ent_0002")
println("Abs Err in total contributions: $total_err")
println("Diff: Body -> $diff_body, Tail -> $diff_tail")
# Out:
# Body contributions: 0.000 -> -1.998723733693351, 0.002 -> -1.9987473372712854
# Tail contributions: 0.000 -> -3.025018655563471e-8, 0.002 -> -5.0740817429012256e-6
# BT Ratio: 0.000 -> 6.607310437631163e7, 0.002 -> 393913.11345497845
# Total contributions: 0.000 -> -1.9987237639435376, 0.002 -> -1.9987524113530284
# Abs Err in total contributions: 2.8647409490822895e-5
# Diff: Body -> 2.3603577934405706e-5, Tail -> 5.043831556345591e-6

# %% [markdown]
# We can do this more generally and just get the truncation error (in terms of pure values).

# %%
function truncation_error(sorted_spec, dev_idx)
    truncated_sorted_spec = sorted_spec[dev_idx : end]
    return sum(truncated_sorted_spec)
end

truncation_error(sorted_spec_0002, dev_index)
# Out:
# 2.5651384857098496e-7

# %%
using LinearAlgebra

function analyze_spectral_fidelity(spec1::Vector{T}, spec2::Vector{T}) where T <: Number

    len = max(length(spec1), length(spec2))
    p = zeros(T, len)
    q = zeros(T, len)
    
    p[1:length(spec1)] = spec1
    q[1:length(spec2)] = spec2
    
    if sum(p) > 0; p ./= sum(p); end
    if sum(q) > 0; q ./= sum(q); end

    bc_coeff = sum(sqrt.(p .* q))
    classical_fidelity = bc_coeff^2

    trace_dist = 0.5 * sum(abs.(p .- q))
    observable_bound = 2 * trace_dist

    return classical_fidelity, trace_dist, observable_bound
end

# --- Example Usage with your previous data ---
# (assuming sorted_spec_0 and sorted_spec_σ exist)

F, D, Bound = analyze_spectral_fidelity(sorted_spec_0000, sorted_spec_0002)
println("Max Possible Fidelity: $F")
println("Observable Bound (||O||=1): $Bound")
# Out:
# Max Possible Fidelity: 0.9999997528930474
# Observable Bound (||O||=1): 2.4081591301462115e-5

# %% [markdown]
# Tail scaling with system size.

# %%
function tail_contribution_with_system_size(N_vals, σ_vals)
    results = Vector{Dict{String, Any}}()

    for N in N_vals

        sorted_spec_0 = sorted_spec(N, 0.00)
        
        if sorted_spec_0 === nothing
            println("Skipping N=$N: No σ=0 data found.")
            continue
        end

        for σ in σ_vals
            # Skip 0.0 if it's in the list, as we compare AGAINST 0.0
            if σ == 0.0
                continue 
            end

            sorted_spec_σ = sorted_spec(N, σ)

            if sorted_spec_σ === nothing
                println("Skipping N=$N, σ=$σ: No data found.")
                continue
            end

            dev_idx = find_tail_divergence(sorted_spec_0, sorted_spec_σ)
            truncation_err = truncation_error(sorted_spec_σ, dev_idx)
            body_cnt_σ = find_body_entropy_contribution(sorted_spec_σ, dev_idx)
            tail_cnt_σ = find_tail_entropy_contribution(sorted_spec_σ, dev_idx)

            fidelity, trace_dist, observable_bound = analyze_spectral_fidelity(sorted_spec_0, sorted_spec_σ)

            results_dict = Dict(
                "N" => N,
                "σ" => σ,
                "dev_idx" => dev_idx,
                "truncation_err" => truncation_err,
                "body_contribution" => body_cnt_σ,
                "tail_contribution" => tail_cnt_σ,
                "total_entropy" => body_cnt_σ + tail_cnt_σ,
                "tail_fraction" => tail_cnt_σ / (body_cnt_σ + tail_cnt_σ), # Useful metric
                "fidelity" => fidelity,
                "trace_dist" => trace_dist,
                "observable_bound" => observable_bound
            )

            push!(results, results_dict)
            
        end # σ loop
    end # N loop

    return results
end

results = tail_contribution_with_system_size(N_vals, [0.001, 0.002])
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# 16-element Vector{Dict{String, Any}}:
#  Dict("fidelity" => 0.9999999495763203, "observable_bound" => 1.960570458020388e-5, "tail_fraction" => 0.01744355438229648, "tail_contribution" => -0.021940328151248707, "truncation_err" => 0.0039676890704699215, "dev_idx" => 6, "N" => 10, "σ" => 0.001, "total_entropy" => -1.2577899933924028, "body_contribution" => -1.2358496652411541…)
#  Dict("fidelity" => 0.9999998665792642, "observable_bound" => 1.0467082187258557e-5, "tail_fraction" => 0.017445556714301178, "tail_contribution" => -0.0219430622015267, "truncation_err" => 0.003968059979885208, "dev_idx" => 6, "N" => 10, "σ" => 0.002, "total_entropy" => -1.2578023482356768, "body_contribution" => -1.2358592860341502…)
#  Dict("fidelity" => 0.9999999480946882, "observable_bound" => 2.424824843651472e-5, "tail_fraction" => 4.2860556528797127e-5, "tail_contribution" => -6.669292162625259e-5, "truncation_err" => 5.4666838721737735e-6, "dev_idx" => 11, "N" => 20, "σ" => 0.001, "total_entropy" => -1.5560442287174452, "body_contribution" => -1.555977535795819…)
#  Dict("fidelity" => 0.9999997385641366, "observable_bound" => 3.7169567861651887e-6, "tail_fraction" => 4.5245969947115245e-5, "tail_contribution" => -7.040370188576793e-5, "truncation_err" => 5.6735843938341375e-6, "dev_idx" => 11, "N" => 20, "σ" => 0.002, "total_entropy" => -1.556021496899232, "body_contribution" => -1.5559510931973464…)
#  Dict("fidelity" => 0.9999999431752012, "observable_bound" => 1.3029163927937478e-5, "tail_fraction" => 7.326258199249979e-7, "tail_contribution" => -1.282180614007337e-6, "truncation_err" => 6.317997946021018e-8, "dev_idx" => 16, "N" => 30, "σ" => 0.001, "total_entropy" => -1.7501166067810705, "body_contribution" => -1.7501153246004566…)
#  Dict("fidelity" => 0.9999997693241542, "observable_bound" => 7.583050370465844e-5, "tail_fraction" => 2.615893687473725e-6, "tail_contribution" => -4.578299710369873e-6, "truncation_err" => 2.389272045401965e-7, "dev_idx" => 16, "N" => 30, "σ" => 0.002, "total_entropy" => -1.7501856945842944, "body_contribution" => -1.750181116284584…)
#  Dict("fidelity" => 0.9999999330416589, "observable_bound" => 3.685021412697567e-5, "tail_fraction" => 7.354689054212818e-7, "tail_contribution" => -1.3898364286176086e-6, "truncation_err" => 6.684184723429127e-8, "dev_idx" => 20, "N" => 40, "σ" => 0.001, "total_entropy" => -1.8897283330034196, "body_contribution" => -1.889726943166991…)
#  Dict("fidelity" => 0.9999997799121628, "observable_bound" => 5.51324001251792e-5, "tail_fraction" => 2.2156329364158136e-6, "tail_contribution" => -4.186751914583243e-6, "truncation_err" => 2.1344827572856923e-7, "dev_idx" => 20, "N" => 40, "σ" => 0.002, "total_entropy" => -1.8896414860830109, "body_contribution" => -1.8896372993310964…)
#  Dict("fidelity" => 0.9999999351360126, "observable_bound" => 7.944158968021025e-6, "tail_fraction" => 6.82791059607123e-7, "tail_contribution" => -1.364706145549607e-6, "truncation_err" => 6.438658437681038e-8, "dev_idx" => 23, "N" => 50, "σ" => 0.001, "total_entropy" => -1.9987170692229876, "body_contribution" => -1.998715704516842…)
#  Dict("fidelity" => 0.9999997528930474, "observable_bound" => 2.4081591301462115e-5, "tail_fraction" => 2.5386244509725917e-6, "tail_contribution" => -5.0740817429012256e-6, "truncation_err" => 2.5651384857098496e-7, "dev_idx" => 21, "N" => 50, "σ" => 0.002, "total_entropy" => -1.9987524113530284, "body_contribution" => -1.9987473372712854…)
#  Dict("fidelity" => 0.9999999419194094, "observable_bound" => 1.1272630445579175e-5, "tail_fraction" => 6.161030822351151e-7, "tail_contribution" => -1.2865362239201726e-6, "truncation_err" => 5.97520789940351e-8, "dev_idx" => 24, "N" => 60, "σ" => 0.001, "total_entropy" => -2.088183391735101, "body_contribution" => -2.0881821051988774…)
#  Dict("fidelity" => 0.9999997501594479, "observable_bound" => 1.789206155366583e-5, "tail_fraction" => 2.4415526308090024e-6, "tail_contribution" => -5.09849249960061e-6, "truncation_err" => 2.5347599486279506e-7, "dev_idx" => 24, "N" => 60, "σ" => 0.002, "total_entropy" => -2.088217323380507, "body_contribution" => -2.0882122248880073…)
#  Dict("fidelity" => 0.9999999382621675, "observable_bound" => 9.526375485765851e-7, "tail_fraction" => 6.280395883712529e-7, "tail_contribution" => -1.3591133484093447e-6, "truncation_err" => 6.240877738578248e-8, "dev_idx" => 27, "N" => 70, "σ" => 0.001, "total_entropy" => -2.164056810390004, "body_contribution" => -2.1640554512766554…)
#  Dict("fidelity" => 0.9999997742184811, "observable_bound" => 3.6411997973549377e-6, "tail_fraction" => 2.123969511929246e-6, "tail_contribution" => -4.596391661028038e-6, "truncation_err" => 2.2438754951992888e-7, "dev_idx" => 27, "N" => 70, "σ" => 0.002, "total_entropy" => -2.1640572688131665, "body_contribution" => -2.1640526724215055…)
#  Dict("fidelity" => 0.999999939348601, "observable_bound" => 2.958358034303422e-7, "tail_fraction" => 6.12122823208565e-7, "tail_contribution" => -1.3649323033679708e-6, "truncation_err" => 6.222448283304277e-8, "dev_idx" => 28, "N" => 80, "σ" => 0.001, "total_entropy" => -2.2298340326756705, "body_contribution" => -2.2298326677433673…)
#  Dict("fidelity" => 0.9999997517423932, "observable_bound" => 2.8487046447566517e-5, "tail_fraction" => 2.312063406422839e-6, "tail_contribution" => -5.155458690561835e-6, "truncation_err" => 2.5091249984779695e-7, "dev_idx" => 28, "N" => 80, "σ" => 0.002, "total_entropy" => -2.2298085235206497, "body_contribution" => -2.229803368061959…)

# %%
using Plots

function plot_deviated_index(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Deviation index (k) vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Deviation index (k)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["dev_idx"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2,
            alpha=0.7
        )
    end
    
    return p
end

plot_deviated_index(results)

# %%
using Plots

function plot_deviated_index(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Truncation Err vs Deviation Index",
        xlabel = "Deviation Index (k)",
        ylabel = "Truncation Error",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        yscale = :log
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["dev_idx"] for d in sigma_data]
        y_vals = [d["truncation_err"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2,
            alpha=0.7
        )
    end
    
    return p
end

plot_deviated_index(results)

# %%
using Plots

function plot_truncation_err_vs_N(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Truncation Error vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Tail Entropy (S_tail)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        yscale = :log,
        yaxis=:log
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["truncation_err"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2
        )
    end
    
    return p
end

plot_truncation_err_vs_N(results)

# %%
using Plots

"""
Plots the Absolute Tail Entropy (S_tail) as a function of System Size (N).
"""
function plot_tail_vs_N(results::Vector{Dict{String, Any}})
    # 1. Identify all unique disorder values to make separate lines
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # 2. Setup the Canvas
    p = plot(
        title = "Tail Entropy Contribution vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Tail Entropy (S_tail)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        # yscale = :log,
        # yaxis=:log
    )
    
    # 3. Loop through each sigma and plot a series
    for σ in unique_sigmas
        # Filter results for this specific sigma
        sigma_data = filter(d -> d["σ"] == σ, results)
        
        # Sort by N so the line connects points in order
        sort!(sigma_data, by = d -> d["N"])
        
        # Extract coordinates
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["tail_contribution"] for d in sigma_data]
        
        # Plot line
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2
        )
    end
    
    display(p)
    return p
end

plot_tail_vs_N(results)

println("")

# %%
function plot_tail_fraction_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Tail Fraction vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Fraction (S_tail / S_total)",
        legend = :topright,
        grid = true,
        bg_legend = :transparent,
        yscale= :log10
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["tail_fraction"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :square, 
            linewidth = 2,
            linestyle = :dash
        )
    end
    
    # display(p)
    return p
end

plot_tail_fraction_vs_N(results)

# %%
function plot_fidelity_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # Linear scale is better for Fidelity since it's close to 1
    p = plot(title="Spectral Fidelity vs N", xlabel="System Size (N)", ylabel="Fidelity (F)",
             legend=:bottomleft, grid=true, bg_legend=:transparent,
             ylims=(0.9999995, 1.00)) # Zoom in near 1.0
    
    for σ in unique_sigmas
        data = filter(d -> d["σ"] == σ, results)
        sort!(data, by = d -> d["N"])
        x = Float64[d["N"] for d in data]; y = Float64[d["fidelity"] for d in data]
        
        plot!(p, x, y, label="σ=$σ", marker=:diamond, lw=2)
    end
    return p
end

plot_fidelity_vs_N(results)

# %%
function plot_observable_error_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # Linear scale is better for Fidelity since it's close to 1
    p = plot(title="Observable Bound vs N", xlabel="System Size (N)", ylabel="Observable Bound",
             legend=:topright, grid=true, bg_legend=:transparent)
    
    for σ in unique_sigmas
        data = filter(d -> d["σ"] == σ, results)
        sort!(data, by = d -> d["N"])
        x = Float64[d["N"] for d in data]; y = Float64[d["observable_bound"] for d in data]
        
        plot!(p, x, y, label="σ=$σ", marker=:diamond, lw=2)
    end
    return p
end

plot_observable_error_vs_N(results)

# %%
using Pkg
Pkg.add(["LinearAlgebra", "ITensors", "ITensorMPS", "Statistics", "JLD2", "FileIO"])

using LinearAlgebra
using ITensors
using ITensorMPS
using Statistics
using JLD2, FileIO

function generate_fully_connected_wam(N::Int, σ::Float64; μ::Float64=1.0)
    """
    Create a weighted adjacency matrix for a fully connected graph of N nodes. μ should always be one really.
    """
 
    A = zeros(Float64, N, N)
    for i in 1:N
        for j in (i+1):N
            weight = μ + σ * randn() # weight from normal distribution with mean μ and std σ
            A[i, j] = weight
            A[j, i] = weight 
        end
    end
    return A
end 

function create_xxz_hamiltonian_mpo(N, adj_mat, J, Δ, sites)
    """Create the XXZ Hamiltonian as an MPO given an adjacency matrix."""
    ampo = OpSum()
    for i = 1:N-1
        for j = i+1:N
            weight = adj_mat[i, j]
            if weight != 0.0
                # XX and YY terms: S+S- + S-S+ = 2(SxSx + SySy)
                # So to get J(SxSx + SySy), we need J/2 * (S+S- + S-S+)
                ampo += weight * J/2, "S+", i, "S-", j
                ampo += weight * J/2, "S-", i, "S+", j
                # ZZ term
                ampo += weight * J * Δ, "Sz", i, "Sz", j
            end
        end
    end
    H = MPO(ampo, sites)
    return H
end 

function solve_xxz_hamiltonian_dmrg(H, ψ0, sweeps::Int=10, bond_dim::Int=1000, cutoff::Float64=1E-14)
    """Solves the XXZ Hamiltonian using DMRG with given parameters. Returns the ground state energy and MPS. """
    swps = Sweeps(sweeps)
    setmaxdim!(swps, bond_dim)
    setcutoff!(swps, cutoff)
    E, ψ = dmrg(H, ψ0, swps; outputlevel=0)
    return E, ψ # only ground state and ground state wavefunction
end

function create_MPS(L::Int, conserve_qns::Bool=true)
    """Create a random MPS for a spin-1/2 chain of length L with bond dimension Χ."""
    # create a site set for a spin-1/2 chain
    sites = siteinds("S=1/2", L; conserve_qns=conserve_qns) # conserve total Sz

    # create a random MPS with bond dimension Χ
    init_state = [isodd(i) ? "Up" : "Dn" for i = 1:L] # antiferromagnetic ground state
    # THIS IS IMPORTANT - SEE NOTE BELOW
    # it sets the subspace of states we are allowed to explore
    # for example, this init_state means we only explore states with total Sz = 0 (i.e. zero magnetisation)
    # this is a reasonable assumption for positive J, but not for negative J
    # if we want to explore ferromagnetic states (negative J), we would need a different init_state
    # USE create_custom_MPS TO SET A DIFFERENT INIT STATE
    ψ0 = MPS(sites, init_state)
    return ψ0, sites
end

function find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    ψ_mps_N, sites_N = create_MPS(N)
    wam_N = generate_fully_connected_wam(N, σ; μ)
    H_N = create_xxz_hamiltonian_mpo(N, wam_N, J, Δ, sites_N)
    _, ψ_gs_N = solve_xxz_hamiltonian_dmrg(H_N, ψ_mps_N, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    return ψ_gs_N
end

function get_entanglement_data(psi, b)
    orthogonalize!(psi, b)
    s = siteind(psi, b)
    
    local U, S, V
    if b==1
        # no link to left, edge case
        U, S, V = svd(psi[b], (s,))
    else
        l = linkind(psi, b-1)
        U, S, V = svd(psi[b], (l, s))
    end

    schmidt_coefs = diag(S)
    schmidt_spectrum = schmidt_coefs .^ 2 # square all schmidt_coefs
    schmidt_spectrum = schmidt_spectrum[schmidt_spectrum .> 1e-20] # filter out really small p so we don't get NaN entropies
    schmidt_spectrum ./= sum(schmidt_spectrum) # normalise

    vn_entropy = -sum(p * log(p) for p in schmidt_spectrum) # von neuman entropy

    return schmidt_coefs, vn_entropy
end

function sort_spectrum(run_coefs)
    spectrum = run_coefs .^ 2
    # spectrum = spectrum[spectrum .> 1e-15]
    spectrum ./= sum(spectrum)
    
    sorted_indices = sortperm(spectrum, rev=true)
    sorted_spec = spectrum[sorted_indices]
    return sorted_spec
end

function get_bipartite_sorted_spectrum(gs_mps)
    b = ceil(Int, N / 2) # bipartite cut
    schmidt_coefs, _ = get_entanglement_data(gs_mps, b)
    return sort_spectrum(schmidt_coefs)
end
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
# sort_spectrum (generic function with 1 method)

# %%
J = Δ = -1
μ = 1.0

NUM_SWEEPS = 30
MAX_BOND_DIM = typemax(Int) # as high as ram allows
ACC = eps(Float64) # machine precision
# Out:
# 2.220446049250313e-16

# %%
function find_approximation_MPS(N, σ, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)

    # first get mps ground state for this system
    # find deviation index k 
    # then find approximable state by limiting max bond dim to k
    
    # first do for sigma=0
    println("Finding ground state MPS states...")
    gs_mps_0 = find_ground_state_mps(N, J, Δ, 0.0, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    gs_mps_σ = find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    println("Found ground state MPS states.")

    # then find the deviation between these. We need the sorted Schmidt coefficients
    println("Finding Schmidt spectrums...")
    b = ceil(Int, N / 2) # bipartite cut
    schmidt_coefs_0, vn_entropy_0 = get_entanglement_data(gs_mps_0, b)
    schmidt_coefs_σ, vn_entropy_σ = get_entanglement_data(gs_mps_σ, b)
    sorted_spec_0 = sort_spectrum(schmidt_coefs_0)
    sorted_spec_σ = sort_spectrum(schmidt_coefs_σ)
    println("Found Schmidt spectrums.")

    # find deviated index

    println("Finding deviation index...")
    dev_idx = find_tail_divergence(sorted_spec_0, sorted_spec_σ)
    println("Found deviation index $dev_idx.")

    # approximable state is then the disordered state run with max bond dim as the dev index
    println("Finding approximate MPS ground state...")
    appx_gs_mps = find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, dev_idx, ACC)
    appx_bond_dim = maxlinkdim(appx_gs_mps)
    println("Found approximate MPS ground state with bond dimension $appx_bond_dim.")

    return appx_gs_mps, gs_mps_σ
    
end
# Out:
# find_approximation_MPS (generic function with 1 method)

# %%
apx_mps, actual_mps = find_approximation_MPS(30, 0.002, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
# Out:
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# (MPS
# [1] ((dim=2|id=622|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=642|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=821|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=5|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=642|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=87|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=389|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=4|id=821|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=991|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=807|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=8|id=389|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=203|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=377|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 4
#  6: QN("Sz",5) => 1, (dim=14|id=807|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=917|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=894|"Link,l=6") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 4
#  3: QN("Sz",-2) => 4
#  4: QN("Sz",0) => 4
#  5: QN("Sz",2) => 4
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=21|id=377|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 4
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=434|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=502|"Link,l=7") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 4
#  4: QN("Sz",-1) => 4
#  5: QN("Sz",1) => 4
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=21|id=894|"Link,l=6") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 4
#  3: QN("Sz",-2) => 4
#  4: QN("Sz",0) => 4
#  5: QN("Sz",2) => 4
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [8] ((dim=2|id=85|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=688|"Link,l=8") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 3
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=21|id=502|"Link,l=7") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 4
#  4: QN("Sz",-1) => 4
#  5: QN("Sz",1) => 4
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [9] ((dim=2|id=976|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=210|"Link,l=9") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 2
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 2
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=21|id=688|"Link,l=8") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 3
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [10] ((dim=2|id=373|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=564|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 2
#  4: QN("Sz",-4) => 2
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 2
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=21|id=210|"Link,l=9") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 2
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 2
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [11] ((dim=2|id=265|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=666|"Link,l=11") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 2
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=21|id=564|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 2
#  4: QN("Sz",-4) => 2
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 2
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=199|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=256|"Link,l=12") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 2
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 2
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=21|id=666|"Link,l=11") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 2
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [13] ((dim=2|id=159|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=213|"Link,l=13") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 2
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 3
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 2
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=21|id=256|"Link,l=12") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 2
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 2
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [14] ((dim=2|id=132|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=478|"Link,l=14") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 3
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=21|id=213|"Link,l=13") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 2
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 3
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 2
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [15] ((dim=2|id=97|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=163|"Link,l=15") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 3
#  9: QN("Sz",1) => 3
#  10: QN("Sz",3) => 2
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1, (dim=21|id=478|"Link,l=14") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 3
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [16] ((dim=2|id=648|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=220|"Link,l=16") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 3
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=21|id=163|"Link,l=15") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 3
#  9: QN("Sz",1) => 3
#  10: QN("Sz",3) => 2
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1)
# [17] ((dim=2|id=39|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=847|"Link,l=17") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 3
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 3
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=21|id=220|"Link,l=16") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 3
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [18] ((dim=2|id=109|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=102|"Link,l=18") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 2
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 2
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=21|id=847|"Link,l=17") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 3
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 3
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [19] ((dim=2|id=960|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=76|"Link,l=19") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 2
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=21|id=102|"Link,l=18") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 2
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 2
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [20] ((dim=2|id=373|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=189|"Link,l=20") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 3
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 3
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=21|id=76|"Link,l=19") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 2
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [21] ((dim=2|id=18|"S=1/2,Site,n=21") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=950|"Link,l=21") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 2
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 4
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=21|id=189|"Link,l=20") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 3
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 3
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [22] ((dim=2|id=287|"S=1/2,Site,n=22") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=864|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=21|id=950|"Link,l=21") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 2
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 4
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [23] ((dim=2|id=76|"S=1/2,Site,n=23") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=532|"Link,l=23") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 4
#  4: QN("Sz",-1) => 4
#  5: QN("Sz",1) => 4
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=21|id=864|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [24] ((dim=2|id=787|"S=1/2,Site,n=24") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=580|"Link,l=24") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 4
#  4: QN("Sz",0) => 5
#  5: QN("Sz",2) => 4
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=21|id=532|"Link,l=23") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 4
#  4: QN("Sz",-1) => 4
#  5: QN("Sz",1) => 4
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [25] ((dim=2|id=929|"S=1/2,Site,n=25") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=21|id=612|"Link,l=25") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 4
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=21|id=580|"Link,l=24") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 4
#  4: QN("Sz",0) => 5
#  5: QN("Sz",2) => 4
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [26] ((dim=2|id=716|"S=1/2,Site,n=26") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=515|"Link,l=26") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=21|id=612|"Link,l=25") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 4
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [27] ((dim=2|id=594|"S=1/2,Site,n=27") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=891|"Link,l=27") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=14|id=515|"Link,l=26") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [28] ((dim=2|id=594|"S=1/2,Site,n=28") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=239|"Link,l=28") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=891|"Link,l=27") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [29] ((dim=2|id=833|"S=1/2,Site,n=29") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=525|"Link,l=29") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=239|"Link,l=28") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [30] ((dim=2|id=99|"S=1/2,Site,n=30") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=525|"Link,l=29") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , MPS
# [1] ((dim=2|id=847|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=475|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=495|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=475|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=3|id=15|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=923|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=3|id=15|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",-2) => 1, (dim=4|id=188|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=225|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=188|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",-3) => 1, (dim=5|id=116|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 1
#  3: QN("Sz",0) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=554|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=5|id=116|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 1
#  3: QN("Sz",0) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",-4) => 1, (dim=6|id=338|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 1
#  3: QN("Sz",1) => 1
#  4: QN("Sz",-1) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-5) => 1)
# [6] ((dim=2|id=721|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=338|"Link,l=5") <Out>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 1
#  3: QN("Sz",1) => 1
#  4: QN("Sz",-1) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-5) => 1, (dim=7|id=621|"Link,l=6") <In>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 1
#  3: QN("Sz",2) => 1
#  4: QN("Sz",0) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-6) => 1)
# [7] ((dim=2|id=76|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=7|id=621|"Link,l=6") <Out>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 1
#  3: QN("Sz",2) => 1
#  4: QN("Sz",0) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-6) => 1, (dim=8|id=19|"Link,l=7") <In>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 1
#  3: QN("Sz",3) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-5) => 1
#  8: QN("Sz",-7) => 1)
# [8] ((dim=2|id=28|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=19|"Link,l=7") <Out>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 1
#  3: QN("Sz",3) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-5) => 1
#  8: QN("Sz",-7) => 1, (dim=9|id=884|"Link,l=8") <In>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 1
#  3: QN("Sz",4) => 1
#  4: QN("Sz",2) => 1
#  5: QN("Sz",0) => 1
#  6: QN("Sz",-2) => 1
#  7: QN("Sz",-4) => 1
#  8: QN("Sz",-6) => 1
#  9: QN("Sz",-8) => 1)
# [9] ((dim=2|id=80|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=9|id=884|"Link,l=8") <Out>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 1
#  3: QN("Sz",4) => 1
#  4: QN("Sz",2) => 1
#  5: QN("Sz",0) => 1
#  6: QN("Sz",-2) => 1
#  7: QN("Sz",-4) => 1
#  8: QN("Sz",-6) => 1
#  9: QN("Sz",-8) => 1, (dim=10|id=310|"Link,l=9") <In>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 1
#  3: QN("Sz",5) => 1
#  4: QN("Sz",3) => 1
#  5: QN("Sz",1) => 1
#  6: QN("Sz",-1) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-5) => 1
#  9: QN("Sz",-7) => 1
#  10: QN("Sz",-9) => 1)
# [10] ((dim=2|id=185|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=10|id=310|"Link,l=9") <Out>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 1
#  3: QN("Sz",5) => 1
#  4: QN("Sz",3) => 1
#  5: QN("Sz",1) => 1
#  6: QN("Sz",-1) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-5) => 1
#  9: QN("Sz",-7) => 1
#  10: QN("Sz",-9) => 1, (dim=11|id=47|"Link,l=10") <In>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 1
#  3: QN("Sz",6) => 1
#  4: QN("Sz",4) => 1
#  5: QN("Sz",2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",-4) => 1
#  9: QN("Sz",-6) => 1
#  10: QN("Sz",-8) => 1
#  11: QN("Sz",-10) => 1)
# [11] ((dim=2|id=130|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=47|"Link,l=10") <Out>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 1
#  3: QN("Sz",6) => 1
#  4: QN("Sz",4) => 1
#  5: QN("Sz",2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",-4) => 1
#  9: QN("Sz",-6) => 1
#  10: QN("Sz",-8) => 1
#  11: QN("Sz",-10) => 1, (dim=12|id=328|"Link,l=11") <In>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 1
#  3: QN("Sz",7) => 1
#  4: QN("Sz",5) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",1) => 1
#  7: QN("Sz",-1) => 1
#  8: QN("Sz",-3) => 1
#  9: QN("Sz",-5) => 1
#  10: QN("Sz",-7) => 1
#  11: QN("Sz",-9) => 1
#  12: QN("Sz",-11) => 1)
# [12] ((dim=2|id=187|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=12|id=328|"Link,l=11") <Out>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 1
#  3: QN("Sz",7) => 1
#  4: QN("Sz",5) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",1) => 1
#  7: QN("Sz",-1) => 1
#  8: QN("Sz",-3) => 1
#  9: QN("Sz",-5) => 1
#  10: QN("Sz",-7) => 1
#  11: QN("Sz",-9) => 1
#  12: QN("Sz",-11) => 1, (dim=13|id=93|"Link,l=12") <In>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 1
#  3: QN("Sz",8) => 1
#  4: QN("Sz",6) => 1
#  5: QN("Sz",4) => 1
#  6: QN("Sz",2) => 1
#  7: QN("Sz",0) => 1
#  8: QN("Sz",-2) => 1
#  9: QN("Sz",-4) => 1
#  10: QN("Sz",-6) => 1
#  11: QN("Sz",-8) => 1
#  12: QN("Sz",-10) => 1
#  13: QN("Sz",-12) => 1)
# [13] ((dim=2|id=229|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=13|id=93|"Link,l=12") <Out>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 1
#  3: QN("Sz",8) => 1
#  4: QN("Sz",6) => 1
#  5: QN("Sz",4) => 1
#  6: QN("Sz",2) => 1
#  7: QN("Sz",0) => 1
#  8: QN("Sz",-2) => 1
#  9: QN("Sz",-4) => 1
#  10: QN("Sz",-6) => 1
#  11: QN("Sz",-8) => 1
#  12: QN("Sz",-10) => 1
#  13: QN("Sz",-12) => 1, (dim=14|id=594|"Link,l=13") <In>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 1
#  3: QN("Sz",9) => 1
#  4: QN("Sz",7) => 1
#  5: QN("Sz",5) => 1
#  6: QN("Sz",3) => 1
#  7: QN("Sz",1) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",-3) => 1
#  10: QN("Sz",-5) => 1
#  11: QN("Sz",-7) => 1
#  12: QN("Sz",-9) => 1
#  13: QN("Sz",-11) => 1
#  14: QN("Sz",-13) => 1)
# [14] ((dim=2|id=677|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=594|"Link,l=13") <Out>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 1
#  3: QN("Sz",9) => 1
#  4: QN("Sz",7) => 1
#  5: QN("Sz",5) => 1
#  6: QN("Sz",3) => 1
#  7: QN("Sz",1) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",-3) => 1
#  10: QN("Sz",-5) => 1
#  11: QN("Sz",-7) => 1
#  12: QN("Sz",-9) => 1
#  13: QN("Sz",-11) => 1
#  14: QN("Sz",-13) => 1, (dim=15|id=235|"Link,l=14") <In>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 1
#  3: QN("Sz",10) => 1
#  4: QN("Sz",8) => 1
#  5: QN("Sz",6) => 1
#  6: QN("Sz",4) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",0) => 1
#  9: QN("Sz",-2) => 1
#  10: QN("Sz",-4) => 1
#  11: QN("Sz",-6) => 1
#  12: QN("Sz",-8) => 1
#  13: QN("Sz",-10) => 1
#  14: QN("Sz",-12) => 1
#  15: QN("Sz",-14) => 1)
# [15] ((dim=2|id=386|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=501|"Link,l=15") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",1) => 1
#  10: QN("Sz",3) => 1
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1, (dim=15|id=235|"Link,l=14") <Out>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 1
#  3: QN("Sz",10) => 1
#  4: QN("Sz",8) => 1
#  5: QN("Sz",6) => 1
#  6: QN("Sz",4) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",0) => 1
#  9: QN("Sz",-2) => 1
#  10: QN("Sz",-4) => 1
#  11: QN("Sz",-6) => 1
#  12: QN("Sz",-8) => 1
#  13: QN("Sz",-10) => 1
#  14: QN("Sz",-12) => 1
#  15: QN("Sz",-14) => 1)
# [16] ((dim=2|id=804|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=15|id=426|"Link,l=16") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 1
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=16|id=501|"Link,l=15") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",1) => 1
#  10: QN("Sz",3) => 1
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1)
# [17] ((dim=2|id=125|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=221|"Link,l=17") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 1
#  8: QN("Sz",1) => 1
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=15|id=426|"Link,l=16") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 1
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [18] ((dim=2|id=627|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=13|id=898|"Link,l=18") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 1
#  7: QN("Sz",0) => 1
#  8: QN("Sz",2) => 1
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=14|id=221|"Link,l=17") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 1
#  8: QN("Sz",1) => 1
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [19] ((dim=2|id=517|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=12|id=578|"Link,l=19") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-1) => 1
#  7: QN("Sz",1) => 1
#  8: QN("Sz",3) => 1
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=13|id=898|"Link,l=18") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 1
#  7: QN("Sz",0) => 1
#  8: QN("Sz",2) => 1
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [20] ((dim=2|id=183|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=210|"Link,l=20") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=12|id=578|"Link,l=19") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-1) => 1
#  7: QN("Sz",1) => 1
#  8: QN("Sz",3) => 1
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [21] ((dim=2|id=932|"S=1/2,Site,n=21") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=10|id=890|"Link,l=21") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=11|id=210|"Link,l=20") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [22] ((dim=2|id=154|"S=1/2,Site,n=22") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=9|id=991|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 1
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=10|id=890|"Link,l=21") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [23] ((dim=2|id=512|"S=1/2,Site,n=23") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=948|"Link,l=23") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 1
#  4: QN("Sz",-1) => 1
#  5: QN("Sz",1) => 1
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=9|id=991|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 1
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [24] ((dim=2|id=392|"S=1/2,Site,n=24") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=7|id=598|"Link,l=24") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 1
#  4: QN("Sz",0) => 1
#  5: QN("Sz",2) => 1
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1, (dim=8|id=948|"Link,l=23") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 1
#  4: QN("Sz",-1) => 1
#  5: QN("Sz",1) => 1
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [25] ((dim=2|id=650|"S=1/2,Site,n=25") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=810|"Link,l=25") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1, (dim=7|id=598|"Link,l=24") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 1
#  4: QN("Sz",0) => 1
#  5: QN("Sz",2) => 1
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1)
# [26] ((dim=2|id=44|"S=1/2,Site,n=26") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=5|id=361|"Link,l=26") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 1
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1, (dim=6|id=810|"Link,l=25") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1)
# [27] ((dim=2|id=805|"S=1/2,Site,n=27") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=618|"Link,l=27") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 1
#  3: QN("Sz",1) => 1
#  4: QN("Sz",3) => 1, (dim=5|id=361|"Link,l=26") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 1
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1)
# [28] ((dim=2|id=905|"S=1/2,Site,n=28") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=3|id=193|"Link,l=28") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1, (dim=4|id=618|"Link,l=27") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 1
#  3: QN("Sz",1) => 1
#  4: QN("Sz",3) => 1)
# [29] ((dim=2|id=515|"S=1/2,Site,n=29") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=373|"Link,l=29") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=3|id=193|"Link,l=28") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 1
#  3: QN("Sz",2) => 1)
# [30] ((dim=2|id=537|"S=1/2,Site,n=30") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=373|"Link,l=29") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , MPS
# [1] ((dim=2|id=574|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=233|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=457|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=233|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=297|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=663|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=297|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=620|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=121|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=620|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=15|id=173|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=748|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=15|id=173|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1, (dim=26|id=808|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 7
#  4: QN("Sz",-1) => 7
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1)
# [6] ((dim=2|id=36|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=26|id=808|"Link,l=5") <Out>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 7
#  4: QN("Sz",-1) => 7
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1, (dim=43|id=669|"Link,l=6") <In>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 9
#  4: QN("Sz",0) => 11
#  5: QN("Sz",-2) => 9
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1)
# [7] ((dim=2|id=593|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=43|id=669|"Link,l=6") <Out>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 9
#  4: QN("Sz",0) => 11
#  5: QN("Sz",-2) => 9
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1, (dim=62|id=499|"Link,l=7") <In>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 9
#  4: QN("Sz",1) => 14
#  5: QN("Sz",-1) => 14
#  6: QN("Sz",-3) => 9
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1)
# [8] ((dim=2|id=556|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=62|id=499|"Link,l=7") <Out>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 9
#  4: QN("Sz",1) => 14
#  5: QN("Sz",-1) => 14
#  6: QN("Sz",-3) => 9
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1, (dim=81|id=162|"Link,l=8") <In>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 9
#  4: QN("Sz",2) => 15
#  5: QN("Sz",0) => 16
#  6: QN("Sz",-2) => 14
#  7: QN("Sz",-4) => 9
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1)
# [9] ((dim=2|id=200|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=81|id=162|"Link,l=8") <Out>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 9
#  4: QN("Sz",2) => 15
#  5: QN("Sz",0) => 16
#  6: QN("Sz",-2) => 14
#  7: QN("Sz",-4) => 9
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1, (dim=98|id=341|"Link,l=9") <In>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 14
#  5: QN("Sz",1) => 16
#  6: QN("Sz",-1) => 16
#  7: QN("Sz",-3) => 14
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [10] ((dim=2|id=684|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=98|id=341|"Link,l=9") <Out>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 14
#  5: QN("Sz",1) => 16
#  6: QN("Sz",-1) => 16
#  7: QN("Sz",-3) => 14
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1, (dim=126|id=662|"Link,l=10") <In>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 10
#  3: QN("Sz",6) => 10
#  4: QN("Sz",4) => 13
#  5: QN("Sz",2) => 19
#  6: QN("Sz",0) => 20
#  7: QN("Sz",-2) => 19
#  8: QN("Sz",-4) => 13
#  9: QN("Sz",-6) => 10
#  10: QN("Sz",-8) => 10
#  11: QN("Sz",-10) => 1)
# [11] ((dim=2|id=237|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=126|id=662|"Link,l=10") <Out>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 10
#  3: QN("Sz",6) => 10
#  4: QN("Sz",4) => 13
#  5: QN("Sz",2) => 19
#  6: QN("Sz",0) => 20
#  7: QN("Sz",-2) => 19
#  8: QN("Sz",-4) => 13
#  9: QN("Sz",-6) => 10
#  10: QN("Sz",-8) => 10
#  11: QN("Sz",-10) => 1, (dim=155|id=157|"Link,l=11") <In>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 11
#  3: QN("Sz",7) => 11
#  4: QN("Sz",5) => 12
#  5: QN("Sz",3) => 20
#  6: QN("Sz",1) => 22
#  7: QN("Sz",-1) => 22
#  8: QN("Sz",-3) => 20
#  9: QN("Sz",-5) => 13
#  10: QN("Sz",-7) => 11
#  11: QN("Sz",-9) => 11
#  12: QN("Sz",-11) => 1)
# [12] ((dim=2|id=576|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=155|id=157|"Link,l=11") <Out>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 11
#  3: QN("Sz",7) => 11
#  4: QN("Sz",5) => 12
#  5: QN("Sz",3) => 20
#  6: QN("Sz",1) => 22
#  7: QN("Sz",-1) => 22
#  8: QN("Sz",-3) => 20
#  9: QN("Sz",-5) => 13
#  10: QN("Sz",-7) => 11
#  11: QN("Sz",-9) => 11
#  12: QN("Sz",-11) => 1, (dim=180|id=629|"Link,l=12") <In>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 12
#  3: QN("Sz",8) => 12
#  4: QN("Sz",6) => 12
#  5: QN("Sz",4) => 18
#  6: QN("Sz",2) => 23
#  7: QN("Sz",0) => 24
#  8: QN("Sz",-2) => 23
#  9: QN("Sz",-4) => 18
#  10: QN("Sz",-6) => 12
#  11: QN("Sz",-8) => 12
#  12: QN("Sz",-10) => 12
#  13: QN("Sz",-12) => 1)
# [13] ((dim=2|id=586|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=180|id=629|"Link,l=12") <Out>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 12
#  3: QN("Sz",8) => 12
#  4: QN("Sz",6) => 12
#  5: QN("Sz",4) => 18
#  6: QN("Sz",2) => 23
#  7: QN("Sz",0) => 24
#  8: QN("Sz",-2) => 23
#  9: QN("Sz",-4) => 18
#  10: QN("Sz",-6) => 12
#  11: QN("Sz",-8) => 12
#  12: QN("Sz",-10) => 12
#  13: QN("Sz",-12) => 1, (dim=212|id=809|"Link,l=13") <In>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 13
#  3: QN("Sz",9) => 13
#  4: QN("Sz",7) => 13
#  5: QN("Sz",5) => 16
#  6: QN("Sz",3) => 24
#  7: QN("Sz",1) => 26
#  8: QN("Sz",-1) => 26
#  9: QN("Sz",-3) => 24
#  10: QN("Sz",-5) => 16
#  11: QN("Sz",-7) => 13
#  12: QN("Sz",-9) => 13
#  13: QN("Sz",-11) => 13
#  14: QN("Sz",-13) => 1)
# [14] ((dim=2|id=303|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=212|id=809|"Link,l=13") <Out>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 13
#  3: QN("Sz",9) => 13
#  4: QN("Sz",7) => 13
#  5: QN("Sz",5) => 16
#  6: QN("Sz",3) => 24
#  7: QN("Sz",1) => 26
#  8: QN("Sz",-1) => 26
#  9: QN("Sz",-3) => 24
#  10: QN("Sz",-5) => 16
#  11: QN("Sz",-7) => 13
#  12: QN("Sz",-9) => 13
#  13: QN("Sz",-11) => 13
#  14: QN("Sz",-13) => 1, (dim=239|id=155|"Link,l=14") <In>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 14
#  3: QN("Sz",10) => 14
#  4: QN("Sz",8) => 14
#  5: QN("Sz",6) => 14
#  6: QN("Sz",4) => 21
#  7: QN("Sz",2) => 27
#  8: QN("Sz",0) => 28
#  9: QN("Sz",-2) => 27
#  10: QN("Sz",-4) => 22
#  11: QN("Sz",-6) => 14
#  12: QN("Sz",-8) => 14
#  13: QN("Sz",-10) => 14
#  14: QN("Sz",-12) => 14
#  15: QN("Sz",-14) => 1)
# [15] ((dim=2|id=86|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=289|id=259|"Link,l=15") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 15
#  3: QN("Sz",-11) => 15
#  4: QN("Sz",-9) => 15
#  5: QN("Sz",-7) => 15
#  6: QN("Sz",-5) => 20
#  7: QN("Sz",-3) => 29
#  8: QN("Sz",-1) => 34
#  9: QN("Sz",1) => 34
#  10: QN("Sz",3) => 30
#  11: QN("Sz",5) => 20
#  12: QN("Sz",7) => 15
#  13: QN("Sz",9) => 15
#  14: QN("Sz",11) => 15
#  15: QN("Sz",13) => 15
#  16: QN("Sz",15) => 1, (dim=239|id=155|"Link,l=14") <Out>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 14
#  3: QN("Sz",10) => 14
#  4: QN("Sz",8) => 14
#  5: QN("Sz",6) => 14
#  6: QN("Sz",4) => 21
#  7: QN("Sz",2) => 27
#  8: QN("Sz",0) => 28
#  9: QN("Sz",-2) => 27
#  10: QN("Sz",-4) => 22
#  11: QN("Sz",-6) => 14
#  12: QN("Sz",-8) => 14
#  13: QN("Sz",-10) => 14
#  14: QN("Sz",-12) => 14
#  15: QN("Sz",-14) => 1)
# [16] ((dim=2|id=331|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=276|id=538|"Link,l=16") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 14
#  3: QN("Sz",-10) => 14
#  4: QN("Sz",-8) => 14
#  5: QN("Sz",-6) => 15
#  6: QN("Sz",-4) => 28
#  7: QN("Sz",-2) => 34
#  8: QN("Sz",0) => 35
#  9: QN("Sz",2) => 34
#  10: QN("Sz",4) => 29
#  11: QN("Sz",6) => 15
#  12: QN("Sz",8) => 14
#  13: QN("Sz",10) => 14
#  14: QN("Sz",12) => 14
#  15: QN("Sz",14) => 1, (dim=289|id=259|"Link,l=15") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 15
#  3: QN("Sz",-11) => 15
#  4: QN("Sz",-9) => 15
#  5: QN("Sz",-7) => 15
#  6: QN("Sz",-5) => 20
#  7: QN("Sz",-3) => 29
#  8: QN("Sz",-1) => 34
#  9: QN("Sz",1) => 34
#  10: QN("Sz",3) => 30
#  11: QN("Sz",5) => 20
#  12: QN("Sz",7) => 15
#  13: QN("Sz",9) => 15
#  14: QN("Sz",11) => 15
#  15: QN("Sz",13) => 15
#  16: QN("Sz",15) => 1)
# [17] ((dim=2|id=339|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=242|id=462|"Link,l=17") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 13
#  3: QN("Sz",-9) => 13
#  4: QN("Sz",-7) => 13
#  5: QN("Sz",-5) => 19
#  6: QN("Sz",-3) => 29
#  7: QN("Sz",-1) => 32
#  8: QN("Sz",1) => 32
#  9: QN("Sz",3) => 30
#  10: QN("Sz",5) => 20
#  11: QN("Sz",7) => 13
#  12: QN("Sz",9) => 13
#  13: QN("Sz",11) => 13
#  14: QN("Sz",13) => 1, (dim=276|id=538|"Link,l=16") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 14
#  3: QN("Sz",-10) => 14
#  4: QN("Sz",-8) => 14
#  5: QN("Sz",-6) => 15
#  6: QN("Sz",-4) => 28
#  7: QN("Sz",-2) => 34
#  8: QN("Sz",0) => 35
#  9: QN("Sz",2) => 34
#  10: QN("Sz",4) => 29
#  11: QN("Sz",6) => 15
#  12: QN("Sz",8) => 14
#  13: QN("Sz",10) => 14
#  14: QN("Sz",12) => 14
#  15: QN("Sz",14) => 1)
# [18] ((dim=2|id=219|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=204|id=25|"Link,l=18") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 12
#  3: QN("Sz",-8) => 12
#  4: QN("Sz",-6) => 12
#  5: QN("Sz",-4) => 22
#  6: QN("Sz",-2) => 28
#  7: QN("Sz",0) => 29
#  8: QN("Sz",2) => 28
#  9: QN("Sz",4) => 23
#  10: QN("Sz",6) => 12
#  11: QN("Sz",8) => 12
#  12: QN("Sz",10) => 12
#  13: QN("Sz",12) => 1, (dim=242|id=462|"Link,l=17") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 13
#  3: QN("Sz",-9) => 13
#  4: QN("Sz",-7) => 13
#  5: QN("Sz",-5) => 19
#  6: QN("Sz",-3) => 29
#  7: QN("Sz",-1) => 32
#  8: QN("Sz",1) => 32
#  9: QN("Sz",3) => 30
#  10: QN("Sz",5) => 20
#  11: QN("Sz",7) => 13
#  12: QN("Sz",9) => 13
#  13: QN("Sz",11) => 13
#  14: QN("Sz",13) => 1)
# [19] ((dim=2|id=269|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=190|id=861|"Link,l=19") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 11
#  3: QN("Sz",-7) => 11
#  4: QN("Sz",-5) => 16
#  5: QN("Sz",-3) => 27
#  6: QN("Sz",-1) => 29
#  7: QN("Sz",1) => 29
#  8: QN("Sz",3) => 27
#  9: QN("Sz",5) => 16
#  10: QN("Sz",7) => 11
#  11: QN("Sz",9) => 11
#  12: QN("Sz",11) => 1, (dim=204|id=25|"Link,l=18") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 12
#  3: QN("Sz",-8) => 12
#  4: QN("Sz",-6) => 12
#  5: QN("Sz",-4) => 22
#  6: QN("Sz",-2) => 28
#  7: QN("Sz",0) => 29
#  8: QN("Sz",2) => 28
#  9: QN("Sz",4) => 23
#  10: QN("Sz",6) => 12
#  11: QN("Sz",8) => 12
#  12: QN("Sz",10) => 12
#  13: QN("Sz",12) => 1)
# [20] ((dim=2|id=96|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=160|id=839|"Link,l=20") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 11
#  4: QN("Sz",-4) => 19
#  5: QN("Sz",-2) => 26
#  6: QN("Sz",0) => 27
#  7: QN("Sz",2) => 26
#  8: QN("Sz",4) => 19
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1, (dim=190|id=861|"Link,l=19") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 11
#  3: QN("Sz",-7) => 11
#  4: QN("Sz",-5) => 16
#  5: QN("Sz",-3) => 27
#  6: QN("Sz",-1) => 29
#  7: QN("Sz",1) => 29
#  8: QN("Sz",3) => 27
#  9: QN("Sz",5) => 16
#  10: QN("Sz",7) => 11
#  11: QN("Sz",9) => 11
#  12: QN("Sz",11) => 1)
# [21] ((dim=2|id=490|"S=1/2,Site,n=21") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=131|id=975|"Link,l=21") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 11
#  4: QN("Sz",-3) => 21
#  5: QN("Sz",-1) => 23
#  6: QN("Sz",1) => 24
#  7: QN("Sz",3) => 21
#  8: QN("Sz",5) => 11
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1, (dim=160|id=839|"Link,l=20") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 11
#  4: QN("Sz",-4) => 19
#  5: QN("Sz",-2) => 26
#  6: QN("Sz",0) => 27
#  7: QN("Sz",2) => 26
#  8: QN("Sz",4) => 19
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1)
# [22] ((dim=2|id=121|"S=1/2,Site,n=22") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=102|id=972|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 13
#  4: QN("Sz",-2) => 19
#  5: QN("Sz",0) => 20
#  6: QN("Sz",2) => 19
#  7: QN("Sz",4) => 13
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1, (dim=131|id=975|"Link,l=21") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 11
#  4: QN("Sz",-3) => 21
#  5: QN("Sz",-1) => 23
#  6: QN("Sz",1) => 24
#  7: QN("Sz",3) => 21
#  8: QN("Sz",5) => 11
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1)
# [23] ((dim=2|id=693|"S=1/2,Site,n=23") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=72|id=641|"Link,l=23") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 12
#  4: QN("Sz",-1) => 16
#  5: QN("Sz",1) => 16
#  6: QN("Sz",3) => 12
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1, (dim=102|id=972|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 13
#  4: QN("Sz",-2) => 19
#  5: QN("Sz",0) => 20
#  6: QN("Sz",2) => 19
#  7: QN("Sz",4) => 13
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1)
# [24] ((dim=2|id=587|"S=1/2,Site,n=24") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=49|id=650|"Link,l=24") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 11
#  4: QN("Sz",0) => 13
#  5: QN("Sz",2) => 11
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=72|id=641|"Link,l=23") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 12
#  4: QN("Sz",-1) => 16
#  5: QN("Sz",1) => 16
#  6: QN("Sz",3) => 12
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1)
# [25] ((dim=2|id=969|"S=1/2,Site,n=25") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=28|id=496|"Link,l=25") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 8
#  4: QN("Sz",1) => 8
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=49|id=650|"Link,l=24") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 11
#  4: QN("Sz",0) => 13
#  5: QN("Sz",2) => 11
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [26] ((dim=2|id=542|"S=1/2,Site,n=26") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=15|id=655|"Link,l=26") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=28|id=496|"Link,l=25") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 8
#  4: QN("Sz",1) => 8
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [27] ((dim=2|id=704|"S=1/2,Site,n=27") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=247|"Link,l=27") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=15|id=655|"Link,l=26") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [28] ((dim=2|id=880|"S=1/2,Site,n=28") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=947|"Link,l=28") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=247|"Link,l=27") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [29] ((dim=2|id=697|"S=1/2,Site,n=29") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=651|"Link,l=29") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=947|"Link,l=28") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [30] ((dim=2|id=34|"S=1/2,Site,n=30") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=651|"Link,l=29") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# )

# %%
function appx_results(N_vals, σ_vals)
    results = Vector{Dict{String, Any}}()

    for N in N_vals
        for σ in σ_vals
            println("N=$N, σ=$σ")
            apx, act = find_approximation_MPS(N, σ, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)

            results_dict = Dict(
                "N" => N,
                "σ" => σ,
                "apx" => apx,
                "act" => act
            )

            push!(results, results_dict)
            
        end # σ loop
    end # N loop

    return results
end

N_vals = 10:10:60
results = appx_results(N_vals, [0.001, 0.002])
# Out:
# N=10, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 6.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=10, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 6.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=20, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 11.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=20, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 11.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=30, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=30, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=40, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 20.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=40, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 20.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=50, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 23.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=50, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 21.
# Finding approximate MPS ground state...
# InterruptException:
#
# Stacktrace:
#   [1] offset(bofs::Dictionaries.Dictionary{Block{5}, Int64}, block::Block{5})
#     @ NDTensors ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/blockoffsets.jl:51
#   [2] offset
#     @ ~/.julia/packages/NDTensors/6HwdB/src/tensorstorage/tensorstorage.jl:104 [inlined]
#   [3] offset
#     @ ~/.julia/packages/NDTensors/6HwdB/src/tensor/tensor.jl:330 [inlined]
#   [4] blockview
#     @ ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/blocksparsetensor.jl:324 [inlined]
#   [5] getindex
#     @ ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/blocksparsetensor.jl:319 [inlined]
#   [6] (::NDTensors.var"#180#181"{NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, NTuple{5, Int64}, NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, NTuple{5, Int64}, NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, NTuple{4, Int64}})(contraction_plan_group::Vector{Tuple{Block{5}, Block{4}, Block{5}}})
#     @ NDTensors ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract_generic.jl:108
#   [7] next
#     @ ~/.julia/packages/Transducers/PqRuk/src/library.jl:81 [inlined]
#   [8] macro expansion
#     @ ~/.julia/packages/Transducers/PqRuk/src/core.jl:181 [inlined]
#   [9] macro expansion
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:239 [inlined]
#  [10] macro expansion
#     @ ~/.julia/packages/Transducers/PqRuk/src/simd.jl:41 [inlined]
#  [11] __foldl__
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:238 [inlined]
#  [12] #transduce#141
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:519 [inlined]
#  [13] transduce
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:508 [inlined]
#  [14] #transduce#140
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:502 [inlined]
#  [15] transduce
#     @ ~/.julia/packages/Transducers/PqRuk/src/processes.jl:500 [inlined]
#  [16] transduce
#     @ ~/.julia/packages/Transducers/PqRuk/src/executors.jl:150 [inlined]
#  [17] #foreach#8
#     @ ~/.julia/packages/Folds/qbSal/src/reduce.jl:89 [inlined]
#  [18] foreach
#     @ ~/.julia/packages/Folds/qbSal/src/reduce.jl:77 [inlined]
#  [19] _contract!
#     @ ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract_generic.jl:87 [inlined]
#  [20] contract!(R::NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, labelsR::NTuple{5, Int64}, tensor1::NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, labelstensor1::NTuple{5, Int64}, tensor2::NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelstensor2::NTuple{4, Int64}, contraction_plan::Vector{Tuple{Block{5}, Block{4}, Block{5}}}, executor::Transducers.SequentialEx{@NamedTuple{}})
#     @ NDTensors ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract_generic.jl:60
#  [21] contract!
#     @ ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract_sequential.jl:54 [inlined]
#  [22] contract!
#     @ ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract.jl:71 [inlined]
#  [23] contract(tensor1::NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, labelstensor1::NTuple{5, Int64}, tensor2::NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelstensor2::NTuple{4, Int64}, labelsR::NTuple{5, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract.jl:13
#  [24] contract(tensor1::NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, labelstensor1::NTuple{5, Int64}, tensor2::NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelstensor2::NTuple{4, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/6HwdB/src/blocksparse/contract.jl:10
#  [25] _contract(A::NDTensors.BlockSparseTensor{Float64, 5, NTuple{5, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 5}}, B::NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}})
#     @ ITensors ~/.julia/packages/ITensors/Xs85I/src/tensor_operations/tensor_algebra.jl:3
#  [26] _contract(A::ITensor, B::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/Xs85I/src/tensor_operations/tensor_algebra.jl:9
#  [27] contract(A::ITensor, B::ITensor)
#     @ ITensors ~/.julia/packages/ITensors/Xs85I/src/tensor_operations/tensor_algebra.jl:74
#  [28] *
#     @ ~/.julia/packages/ITensors/Xs85I/src/tensor_operations/tensor_algebra.jl:61 [inlined]
#  [29] contract(P::ProjMPO, v::ITensor)
#     @ ITensorMPS ~/.julia/packages/ITensorMPS/AQY99/src/abstractprojmpo/abstractprojmpo.jl:51
#  [30] product(P::ProjMPO, v::ITensor)
#     @ ITensorMPS ~/.julia/packages/ITensorMPS/AQY99/src/abstractprojmpo/abstractprojmpo.jl:71
#  [31] AbstractProjMPO
#     @ ~/.julia/packages/ITensorMPS/AQY99/src/abstractprojmpo/abstractprojmpo.jl:87 [inlined]
#  [32] apply
#     @ ~/.julia/packages/KrylovKit/MlUlm/src/apply.jl:2 [inlined]
#  [33] lanczosrecurrence(operator::ProjMPO, V::KrylovKit.OrthonormalBasis{ITensor}, β::Float64, orth::KrylovKit.ModifiedGramSchmidt2)
#     @ KrylovKit ~/.julia/packages/KrylovKit/MlUlm/src/factorizations/lanczos.jl:325
#  [34] expand!(iter::KrylovKit.LanczosIterator{ProjMPO, ITensor, KrylovKit.ModifiedGramSchmidt2}, state::KrylovKit.LanczosFactorization{ITensor, Float64}; verbosity::Int64)
#     @ KrylovKit ~/.julia/packages/KrylovKit/MlUlm/src/factorizations/lanczos.jl:256
#  [35] eigsolve(A::ProjMPO, x₀::ITensor, howmany::Int64, which::Symbol, alg::KrylovKit.Lanczos{KrylovKit.ModifiedGramSchmidt2, Float64}; alg_rrule::KrylovKit.Arnoldi{KrylovKit.ModifiedGramSchmidt2, Float64})
#     @ KrylovKit ~/.julia/packages/KrylovKit/MlUlm/src/eigsolve/lanczos.jl:78
#  [36] eigsolve
#     @ ~/.julia/packages/KrylovKit/MlUlm/src/eigsolve/lanczos.jl:1 [inlined]
#  [37] #eigsolve#59
#     @ ~/.julia/packages/KrylovKit/MlUlm/src/eigsolve/eigsolve.jl:235 [inlined]
#  [38] eigsolve
#     @ ~/.julia/packages/KrylovKit/MlUlm/src/eigsolve/eigsolve.jl:209 [inlined]
#  [39] macro expansion
#     @ ~/.julia/packages/ITensorMPS/AQY99/src/dmrg.jl:239 [inlined]
#  [40] macro expansion
#     @ ./timing.jl:421 [inlined]
#  [41] dmrg(PH::ProjMPO, psi0::MPS, sweeps::Sweeps; which_decomp::Nothing, svd_alg::Nothing, observer::NoObserver, outputlevel::Int64, write_when_maxdim_exceeds::Nothing, write_path::String, eigsolve_tol::Float64, eigsolve_krylovdim::Int64, eigsolve_maxiter::Int64, eigsolve_verbosity::Int64, eigsolve_which_eigenvalue::Symbol, ishermitian::Bool)
#     @ ITensorMPS ~/.julia/packages/ITensorMPS/AQY99/src/dmrg.jl:206
#  [42] dmrg
#     @ ~/.julia/packages/ITensorMPS/AQY99/src/dmrg.jl:158 [inlined]
#  [43] #dmrg#513
#     @ ~/.julia/packages/ITensorMPS/AQY99/src/dmrg.jl:28 [inlined]
#  [44] dmrg
#     @ ~/.julia/packages/ITensorMPS/AQY99/src/dmrg.jl:21 [inlined]
#  [45] solve_xxz_hamiltonian_dmrg(H::MPO, ψ0::MPS, sweeps::Int64, bond_dim::Int64, cutoff::Float64)
#     @ Main ./In[25]:51
#  [46] find_ground_state_mps(N::Int64, J::Int64, Δ::Int64, σ::Float64, μ::Float64, NUM_SWEEPS::Int64, MAX_BOND_DIM::Int64, ACC::Float64)
#     @ Main ./In[25]:76
#  [47] find_approximation_MPS(N::Int64, σ::Float64, J::Int64, Δ::Int64, μ::Float64, NUM_SWEEPS::Int64, MAX_BOND_DIM::Int64, ACC::Float64)
#     @ Main ./In[28]:30
#  [48] appx_results(N_vals::StepRange{Int64, Int64}, σ_vals::Vector{Float64})
#     @ Main ./In[48]:7

# %%
jldsave("appx_states.jld2", results)

# %%
appx_states = jldopen("appx_states")
