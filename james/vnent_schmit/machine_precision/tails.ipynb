# %%
using JLD2, FileIO
using Plots

data_loc = "simulation_results_mp.jld2"

N_vals = 10:10:80
σ_vals = [0.000, 0.001, 0.002, 0.005, 0.01, 0.05]
# Out:
# 6-element Vector{Float64}:
#  0.0
#  0.001
#  0.002
#  0.005
#  0.01
#  0.05

# %%
function plot_bond_dim_vs_N(N_vals, σ_vals, data_loc)
    
    gr() 
    bond_dim_plot = plot(
        title = "Average Max Bond Dimension vs. System Size",
        xlabel = "System Size (N)",
        ylabel = "Average Max Bond Dimension (χ)",
        legend = :topleft
    )
    
    if !isfile(data_loc)
        println("Error: Results file not found at '$data_loc'")
        println("Please run your 'get_data.jl' simulation script first.")
        return
    end
    

    jldopen(data_loc, "r") do file

        for σ in σ_vals
            plot_N = Float64[]
            plot_chi = Float64[]
            plot_chi_err = Float64[]
            
    
            for N in N_vals
                group_path = "N=$(N)/sigma=$(σ)"
                
        
                if haskey(file, group_path)
        
                    avg_chi = file[group_path]["avg_bond_dim"]
                    err_chi = file[group_path]["err_bond_dim"]
                    
          
                    push!(plot_N, N) 
                    push!(plot_chi, avg_chi)
                    push!(plot_chi_err, err_chi)
                else
                    println("Warning: Missing data for N=$N, σ=$σ. Skipping this point.")
                end
            end
            

            if !isempty(plot_N)
                plot!(
                    bond_dim_plot,
                    plot_N, 
                    plot_chi,
                    yerror = plot_chi_err, 
                    label = "σ = $σ",
                    markersize = 4,
                    capstyle = :round 
                )
            else
                println("No data found for σ = $σ.")
            end
        end
    end
    
    display(bond_dim_plot)

end

plot_bond_dim_vs_N(N_vals, σ_vals, data_loc)
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588

# %%
function plot_schmidt_coefficient_tail_comparison_first_run(N_vals, σ_vals, data_loc)
    """
    Create plots showing Schmidt coefficients sorted by magnitude using the SAME data
    as the entropy contributions plot (first run only).
    """
    
    if !isfile(data_loc)
        println("Error: Results file not found at '$data_loc'")
        return
    end

    gr()
    plot_list = []
    
    jldopen(data_loc, "r") do file
        for N in N_vals
            subplot = plot(
                title = "N = $N",
                xlabel = "Schmidt Index (sorted)",
                ylabel = "Schmidt Coefficient Value (λ)",
                yscale = :log10,
                legend = :topright,
                yaxis = (formatter = :scientific),
            )
            
            for σ in reverse!(σ_vals)
                group_path = "N=$(N)/sigma=$(σ)"
                
                if haskey(file, group_path)
                    all_run_coefs = file[group_path]["schmidt_coefs"]
                    
                    first_run = all_run_coefs[1]
                    
                    if first_run isa Vector{Float64}
                        run_coefs = first_run
                    else
                        run_coefs = first_run.storage.data
                    end
                    
                    spectrum = run_coefs .^ 2
                    # spectrum = spectrum[spectrum .> 1e-15]
                    spectrum ./= sum(spectrum)
                    
                    sorted_indices = sortperm(spectrum, rev=true)
                    sorted_spec = spectrum[sorted_indices]
                    
                    x_vals = 1:length(sorted_spec)
                    
                    plot!(
                        subplot,
                        x_vals,
                        sorted_spec,
                        label = "σ = $σ",
                        linewidth = 2
                    )
                else
                    println("Warning: Missing data for N=$N, σ=$σ")
                end
            end
            
            push!(plot_list, subplot)
        end
    end
    
    final_plot = plot(
        plot_list...,
        layout = (4, 2),
        size = (1400, 1800),
        plot_title = "Schmidt Coefficient Tail Behavior"
    )
    
    display(final_plot)
    savefig(final_plot, "schmidt_coefficient_tails_first_run.png")
    println("Plot saved to schmidt_coefficient_tails_first_run.png")
end

plot_schmidt_coefficient_tail_comparison_first_run(N_vals, σ_vals, data_loc)
# Out:
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# Warning: Missing data for N=30, σ=0.05
# Warning: Missing data for N=30, σ=0.01
# Warning: Missing data for N=30, σ=0.005
# Warning: Missing data for N=40, σ=0.005
# Warning: Missing data for N=40, σ=0.01
# Warning: Missing data for N=40, σ=0.05
# Warning: Missing data for N=50, σ=0.05
# Warning: Missing data for N=50, σ=0.01
# Warning: Missing data for N=50, σ=0.005
# Warning: Missing data for N=60, σ=0.005
# Warning: Missing data for N=60, σ=0.01
# Warning: Missing data for N=60, σ=0.05
# Warning: Missing data for N=70, σ=0.05
# Warning: Missing data for N=70, σ=0.01
# Warning: Missing data for N=70, σ=0.005
# Warning: Missing data for N=80, σ=0.005
# Warning: Missing data for N=80, σ=0.01
# Warning: Missing data for N=80, σ=0.05
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# ┌ Warning: Skipped yaxis arg scientific
# └ @ Plots ~/.julia/packages/Plots/8ZnR3/src/axes.jl:75
# Plot saved to schmidt_coefficient_tails_first_run.png

# %% [markdown]
# Now we want to confirm what the weight of the tail is (i.e. how much does it contribute to the overall VN entropy).
#
# We will do this, by essentially finding the point at which the tail deviates from the $\sigma=0$ case, and summing up all those values. Let's first just see if we can just find that point from which the deviation occurs. We'll write a function to do this for one $N$ and one $\sigma \neq 0$.

# %%
function sorted_spec(N, σ)

    # we need to get the runs for the zero sigma case, and the sigma we entered. 

    if !isfile(data_loc)
        println("Error: results file not found at $data_loc")
        return nothing
    end

    jldopen(data_loc, "r") do file

        # Load σ data
        group_path_σ = "N=$(N)/sigma=$(σ)"
        if !haskey(file, group_path_σ)
            println("Warning: Missing data for N=$N, σ=$σ")
            return nothing
        end
        all_run_coefs_σ = file[group_path_σ]["schmidt_coefs"]
        first_run_σ = all_run_coefs_σ[1]
        if first_run_σ isa Vector{Float64}
            run_coefs_σ = first_run_σ
        else
            run_coefs_σ = first_run_σ.storage.data
        end
        spectrum_σ = run_coefs_σ .^ 2
        # spectrum_σ = spectrum_σ[spectrum_σ .> 1e-15]
        spectrum_σ ./= sum(spectrum_σ)
        sorted_spec_σ = sort(spectrum_σ, rev=true)

        return sorted_spec_σ

    end # end jldopen

end
# Out:
# sorted_spec (generic function with 1 method)

# %%
sorted_spec_0000 = sorted_spec(50, 0.00)
sorted_spec_0001 = sorted_spec(50, 0.001)
sorted_spec_0002 = sorted_spec(50, 0.002)
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# 492-element Vector{Float64}:
#  0.21392592958624593
#  0.2139259295862441
#  0.15717247053859035
#  0.1571724705385896
#  0.08452644299080202
#  0.08452644299079642
#  0.033019654047806095
#  0.033019654047795444
#  0.00925520861155709
#  0.009255208611554102
#  0.0018283288698061914
#  0.0018283288697850486
#  0.00024818924398298817
#  ⋮
#  3.7607862968065194e-17
#  3.760786210873161e-17
#  2.9641759547414484e-17
#  2.961105675071508e-17
#  2.7600421814771014e-17
#  2.757751992608378e-17
#  2.4213614402621422e-17
#  2.370237079807692e-17
#  2.3685058543364174e-17
#  2.133384124250395e-17
#  1.3124781685100149e-17
#  1.3124781667143388e-17

# %%
function find_tail_divergence(clean_spec, disordered_spec; ratio_threshold=5.0, min_val=1e-20)

    for i in 1:min(length(clean_spec), length(disordered_spec))
        val_clean = clean_spec[i]
        val_disordered = disordered_spec[i]
        
        if val_clean < min_val
            if val_disordered > min_val * 10
                return i
            else
                continue 
            end
        end
        ratio = val_disordered / val_clean
        
        if ratio > ratio_threshold
            return i
        end
    end
    
    return length(clean_spec) # Fallback if no deviation found
end

deviation_idx = find_tail_divergence(sorted_spec_0000, sorted_spec_0002, ratio_threshold=5.0)

println("Deviation found at index: $deviation_idx")
# Out:
# Deviation found at index: 21

# %%
function verify_deviation_zoom(clean_spec, disordered_spec, dev_idx; window=15)
    # 1. Define the safe zoom window (clamping to array bounds)
    len = min(length(clean_spec), length(disordered_spec))
    start_idx = max(1, dev_idx - window)
    end_idx = min(len, dev_idx + window)
    
    # The x-axis range
    rng = start_idx:end_idx

    # 2. Base Plot
    p = plot(rng, clean_spec[rng], 
        label="Clean (σ=0)", 
        color=:blue, 
        linestyle=:dash, 
        linewidth=2,
        yscale=:log10,           # Crucial for seeing tails
        marker=:circle,          # distinct points help verify exact indices
        markersize=3,
        title="Zoom around Index $dev_idx",
        xlabel="Schmidt Index",
        ylabel="Eigenvalue (Log Scale)",
        legend=:bottomleft       # Moves legend out of the way of the tail usually
    )

    # 3. Add Disordered Data
    plot!(p, rng, disordered_spec[rng], 
        label="Disordered", 
        color=:red, 
        linewidth=2,
        marker=:diamond,
        markersize=3
    )

    # 4. Highlight the specific cut-off point
    vline!(p, [dev_idx], 
        label="Detected Point", 
        color=:black, 
        linewidth=2,
        linestyle=:dot
    )

    display(p)
end

# 1. Find the index (using the logic from the previous step)
dev_index = find_tail_divergence(sorted_spec_0000, sorted_spec_0002, ratio_threshold=5.0)

# 2. Visual Check
verify_deviation_zoom(sorted_spec_0000, sorted_spec_0002, dev_index, window=20)

# %%
function safe_xlogx(x)
    """handles error when computer tries to do logs with small numbers"""
    if x <= 1e-20
        return 0.0 # xlogx tends to this for small vals anyway
    end
    return x * log(x)
end

function find_body_entropy_contribution(sorted_spec, deivation_idx)
    truncated_sorted_spec = sorted_spec[1 : deviation_idx - 1]
    return sum(safe_xlogx(x) for x in truncated_sorted_spec)
end

function find_tail_entropy_contribution(sorted_spec, deviation_idx)
    truncated_sorted_spec = sorted_spec[deviation_idx : end]
    return sum(safe_xlogx(x) for x in truncated_sorted_spec)
end
# Out:
# find_tail_entropy_contribution (generic function with 1 method)

# %%
# find body and Tail

body_cnt_0000 = find_body_entropy_contribution(sorted_spec_0000, dev_index)
tail_cnt_0000 = find_tail_entropy_contribution(sorted_spec_0000, dev_index)
total_ent_0000 = body_cnt_0000 + tail_cnt_0000
bt_ratio_0000 = body_cnt_0000 / tail_cnt_0000

body_cnt_0002 = find_body_entropy_contribution(sorted_spec_0002, dev_index)
tail_cnt_0002 = find_tail_entropy_contribution(sorted_spec_0002, dev_index)
total_ent_0002 = body_cnt_0002 + tail_cnt_0002
bt_ratio_0002 = body_cnt_0002 / tail_cnt_0002

diff_body = abs(body_cnt_0000 - body_cnt_0002)
diff_tail = abs(tail_cnt_0000 - tail_cnt_0002)
total_err = abs(total_ent_0000 - total_ent_0002)

println("Body contributions: 0.000 -> $body_cnt_0000, 0.002 -> $body_cnt_0002")
println("Tail contributions: 0.000 -> $tail_cnt_0000, 0.002 -> $tail_cnt_0002")
println("BT Ratio: 0.000 -> $bt_ratio_0000, 0.002 -> $bt_ratio_0002")
println("Total contributions: 0.000 -> $total_ent_0000, 0.002 -> $total_ent_0002")
println("Abs Err in total contributions: $total_err")
println("Diff: Body -> $diff_body, Tail -> $diff_tail")
# Out:
# Body contributions: 0.000 -> -1.998723733693351, 0.002 -> -1.9987473372712854
# Tail contributions: 0.000 -> -3.025018655563471e-8, 0.002 -> -5.0740817429012256e-6
# BT Ratio: 0.000 -> 6.607310437631163e7, 0.002 -> 393913.11345497845
# Total contributions: 0.000 -> -1.9987237639435376, 0.002 -> -1.9987524113530284
# Abs Err in total contributions: 2.8647409490822895e-5
# Diff: Body -> 2.3603577934405706e-5, Tail -> 5.043831556345591e-6

# %% [markdown]
# We can do this more generally and just get the truncation error (in terms of pure values).

# %%
function truncation_error(sorted_spec, dev_idx)
    truncated_sorted_spec = sorted_spec[dev_idx : end]
    return sum(truncated_sorted_spec)
end

truncation_error(sorted_spec_0002, dev_index)
# Out:
# 2.5651384857098496e-7

# %%
using LinearAlgebra

function analyze_spectral_fidelity(spec1::Vector{T}, spec2::Vector{T}) where T <: Number

    len = max(length(spec1), length(spec2))
    p = zeros(T, len)
    q = zeros(T, len)
    
    p[1:length(spec1)] = spec1
    q[1:length(spec2)] = spec2
    
    if sum(p) > 0; p ./= sum(p); end
    if sum(q) > 0; q ./= sum(q); end

    bc_coeff = sum(sqrt.(p .* q))
    classical_fidelity = bc_coeff^2

    trace_dist = 0.5 * sum(abs.(p .- q))
    observable_bound = 2 * trace_dist

    return classical_fidelity, trace_dist, observable_bound
end

# --- Example Usage with your previous data ---
# (assuming sorted_spec_0 and sorted_spec_σ exist)

F, D, Bound = analyze_spectral_fidelity(sorted_spec_0000, sorted_spec_0002)
println("Max Possible Fidelity: $F")
println("Observable Bound (||O||=1): $Bound")
# Out:
# Max Possible Fidelity: 0.9999997528930474
# Observable Bound (||O||=1): 2.4081591301462115e-5

# %% [markdown]
# Tail scaling with system size.

# %%
function tail_contribution_with_system_size(N_vals, σ_vals)
    results = Vector{Dict{String, Any}}()

    for N in N_vals

        sorted_spec_0 = sorted_spec(N, 0.00)
        
        if sorted_spec_0 === nothing
            println("Skipping N=$N: No σ=0 data found.")
            continue
        end

        for σ in σ_vals
            # Skip 0.0 if it's in the list, as we compare AGAINST 0.0
            if σ == 0.0
                continue 
            end

            sorted_spec_σ = sorted_spec(N, σ)

            if sorted_spec_σ === nothing
                println("Skipping N=$N, σ=$σ: No data found.")
                continue
            end

            dev_idx = find_tail_divergence(sorted_spec_0, sorted_spec_σ)
            truncation_err = truncation_error(sorted_spec_σ, dev_idx)
            body_cnt_σ = find_body_entropy_contribution(sorted_spec_σ, dev_idx)
            tail_cnt_σ = find_tail_entropy_contribution(sorted_spec_σ, dev_idx)

            fidelity, trace_dist, observable_bound = analyze_spectral_fidelity(sorted_spec_0, sorted_spec_σ)

            results_dict = Dict(
                "N" => N,
                "σ" => σ,
                "dev_idx" => dev_idx,
                "truncation_err" => truncation_err,
                "body_contribution" => body_cnt_σ,
                "tail_contribution" => tail_cnt_σ,
                "total_entropy" => body_cnt_σ + tail_cnt_σ,
                "tail_fraction" => tail_cnt_σ / (body_cnt_σ + tail_cnt_σ), # Useful metric
                "fidelity" => fidelity,
                "trace_dist" => trace_dist,
                "observable_bound" => observable_bound
            )

            push!(results, results_dict)
            
        end # σ loop
    end # N loop

    return results
end

results = tail_contribution_with_system_size(N_vals, [0.001, 0.002])
# Out:
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Dense{Float64,Vector{Float64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# ┌ Warning: type NDTensors.Tensor{Float64,1,JLD2.ReconstructedMutable{Symbol("Dense{Float64,Vector{Float64}}"), (:data,), Tuple{Any}},Tuple{Int64}} does not exist in workspace; reconstructing
# └ @ JLD2 ~/.julia/packages/JLD2/WDhXU/src/data/reconstructing_datatypes.jl:588
# 16-element Vector{Dict{String, Any}}:
#  Dict("fidelity" => 0.9999999495763203, "observable_bound" => 1.960570458020388e-5, "tail_fraction" => 0.01744355438229648, "tail_contribution" => -0.021940328151248707, "truncation_err" => 0.0039676890704699215, "dev_idx" => 6, "N" => 10, "σ" => 0.001, "total_entropy" => -1.2577899933924028, "body_contribution" => -1.2358496652411541…)
#  Dict("fidelity" => 0.9999998665792642, "observable_bound" => 1.0467082187258557e-5, "tail_fraction" => 0.017445556714301178, "tail_contribution" => -0.0219430622015267, "truncation_err" => 0.003968059979885208, "dev_idx" => 6, "N" => 10, "σ" => 0.002, "total_entropy" => -1.2578023482356768, "body_contribution" => -1.2358592860341502…)
#  Dict("fidelity" => 0.9999999480946882, "observable_bound" => 2.424824843651472e-5, "tail_fraction" => 4.2860556528797127e-5, "tail_contribution" => -6.669292162625259e-5, "truncation_err" => 5.4666838721737735e-6, "dev_idx" => 11, "N" => 20, "σ" => 0.001, "total_entropy" => -1.5560442287174452, "body_contribution" => -1.555977535795819…)
#  Dict("fidelity" => 0.9999997385641366, "observable_bound" => 3.7169567861651887e-6, "tail_fraction" => 4.5245969947115245e-5, "tail_contribution" => -7.040370188576793e-5, "truncation_err" => 5.6735843938341375e-6, "dev_idx" => 11, "N" => 20, "σ" => 0.002, "total_entropy" => -1.556021496899232, "body_contribution" => -1.5559510931973464…)
#  Dict("fidelity" => 0.9999999431752012, "observable_bound" => 1.3029163927937478e-5, "tail_fraction" => 7.326258199249979e-7, "tail_contribution" => -1.282180614007337e-6, "truncation_err" => 6.317997946021018e-8, "dev_idx" => 16, "N" => 30, "σ" => 0.001, "total_entropy" => -1.7501166067810705, "body_contribution" => -1.7501153246004566…)
#  Dict("fidelity" => 0.9999997693241542, "observable_bound" => 7.583050370465844e-5, "tail_fraction" => 2.615893687473725e-6, "tail_contribution" => -4.578299710369873e-6, "truncation_err" => 2.389272045401965e-7, "dev_idx" => 16, "N" => 30, "σ" => 0.002, "total_entropy" => -1.7501856945842944, "body_contribution" => -1.750181116284584…)
#  Dict("fidelity" => 0.9999999330416589, "observable_bound" => 3.685021412697567e-5, "tail_fraction" => 7.354689054212818e-7, "tail_contribution" => -1.3898364286176086e-6, "truncation_err" => 6.684184723429127e-8, "dev_idx" => 20, "N" => 40, "σ" => 0.001, "total_entropy" => -1.8897283330034196, "body_contribution" => -1.889726943166991…)
#  Dict("fidelity" => 0.9999997799121628, "observable_bound" => 5.51324001251792e-5, "tail_fraction" => 2.2156329364158136e-6, "tail_contribution" => -4.186751914583243e-6, "truncation_err" => 2.1344827572856923e-7, "dev_idx" => 20, "N" => 40, "σ" => 0.002, "total_entropy" => -1.8896414860830109, "body_contribution" => -1.8896372993310964…)
#  Dict("fidelity" => 0.9999999351360126, "observable_bound" => 7.944158968021025e-6, "tail_fraction" => 6.82791059607123e-7, "tail_contribution" => -1.364706145549607e-6, "truncation_err" => 6.438658437681038e-8, "dev_idx" => 23, "N" => 50, "σ" => 0.001, "total_entropy" => -1.9987170692229876, "body_contribution" => -1.998715704516842…)
#  Dict("fidelity" => 0.9999997528930474, "observable_bound" => 2.4081591301462115e-5, "tail_fraction" => 2.5386244509725917e-6, "tail_contribution" => -5.0740817429012256e-6, "truncation_err" => 2.5651384857098496e-7, "dev_idx" => 21, "N" => 50, "σ" => 0.002, "total_entropy" => -1.9987524113530284, "body_contribution" => -1.9987473372712854…)
#  Dict("fidelity" => 0.9999999419194094, "observable_bound" => 1.1272630445579175e-5, "tail_fraction" => 6.161030822351151e-7, "tail_contribution" => -1.2865362239201726e-6, "truncation_err" => 5.97520789940351e-8, "dev_idx" => 24, "N" => 60, "σ" => 0.001, "total_entropy" => -2.088183391735101, "body_contribution" => -2.0881821051988774…)
#  Dict("fidelity" => 0.9999997501594479, "observable_bound" => 1.789206155366583e-5, "tail_fraction" => 2.4415526308090024e-6, "tail_contribution" => -5.09849249960061e-6, "truncation_err" => 2.5347599486279506e-7, "dev_idx" => 24, "N" => 60, "σ" => 0.002, "total_entropy" => -2.088217323380507, "body_contribution" => -2.0882122248880073…)
#  Dict("fidelity" => 0.9999999382621675, "observable_bound" => 9.526375485765851e-7, "tail_fraction" => 6.280395883712529e-7, "tail_contribution" => -1.3591133484093447e-6, "truncation_err" => 6.240877738578248e-8, "dev_idx" => 27, "N" => 70, "σ" => 0.001, "total_entropy" => -2.164056810390004, "body_contribution" => -2.1640554512766554…)
#  Dict("fidelity" => 0.9999997742184811, "observable_bound" => 3.6411997973549377e-6, "tail_fraction" => 2.123969511929246e-6, "tail_contribution" => -4.596391661028038e-6, "truncation_err" => 2.2438754951992888e-7, "dev_idx" => 27, "N" => 70, "σ" => 0.002, "total_entropy" => -2.1640572688131665, "body_contribution" => -2.1640526724215055…)
#  Dict("fidelity" => 0.999999939348601, "observable_bound" => 2.958358034303422e-7, "tail_fraction" => 6.12122823208565e-7, "tail_contribution" => -1.3649323033679708e-6, "truncation_err" => 6.222448283304277e-8, "dev_idx" => 28, "N" => 80, "σ" => 0.001, "total_entropy" => -2.2298340326756705, "body_contribution" => -2.2298326677433673…)
#  Dict("fidelity" => 0.9999997517423932, "observable_bound" => 2.8487046447566517e-5, "tail_fraction" => 2.312063406422839e-6, "tail_contribution" => -5.155458690561835e-6, "truncation_err" => 2.5091249984779695e-7, "dev_idx" => 28, "N" => 80, "σ" => 0.002, "total_entropy" => -2.2298085235206497, "body_contribution" => -2.229803368061959…)

# %%
using Plots

function plot_deviated_index(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Deviation index (k) vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Deviation index (k)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["dev_idx"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2,
            alpha=0.7
        )
    end
    
    return p
end

plot_deviated_index(results)

# %%
using Plots

function plot_deviated_index(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Truncation Err vs Deviation Index",
        xlabel = "Deviation Index (k)",
        ylabel = "Truncation Error",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        yscale = :log
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["dev_idx"] for d in sigma_data]
        y_vals = [d["truncation_err"] for d in sigma_data] .^2
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2,
            alpha=0.7
        )
    end
    
    return p
end

plot_deviated_index(results)

# %%
using Plots

function plot_truncation_err_vs_N(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Truncation Error vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Tail Entropy (S_tail)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        yscale = :log,
        yaxis=:log
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["truncation_err"] for d in sigma_data] .^2
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2
        )
    end
    epss = eps(Float64)
    hline!(p, [epss], label="EPS $epss")
    
    return p
end

plot_truncation_err_vs_N(results)

# %%
using Plots

"""
Plots the Absolute Tail Entropy (S_tail) as a function of System Size (N).
"""
function plot_tail_vs_N(results::Vector{Dict{String, Any}})
    # 1. Identify all unique disorder values to make separate lines
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # 2. Setup the Canvas
    p = plot(
        title = "Tail Entropy Contribution vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Tail Entropy (S_tail)",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
        # yscale = :log,
        # yaxis=:log
    )
    
    # 3. Loop through each sigma and plot a series
    for σ in unique_sigmas
        # Filter results for this specific sigma
        sigma_data = filter(d -> d["σ"] == σ, results)
        
        # Sort by N so the line connects points in order
        sort!(sigma_data, by = d -> d["N"])
        
        # Extract coordinates
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["tail_contribution"] for d in sigma_data]
        
        # Plot line
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2
        )
    end
    
    display(p)
    return p
end

plot_tail_vs_N(results)

println("")

# %%
function plot_tail_fraction_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Tail Fraction vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Fraction (S_tail / S_total)",
        legend = :topright,
        grid = true,
        bg_legend = :transparent,
        yscale= :log10
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        y_vals = [d["tail_fraction"] for d in sigma_data]
        
        plot!(p, x_vals, y_vals, 
            label = "σ = $σ", 
            marker = :square, 
            linewidth = 2,
            linestyle = :dash
        )
    end
    
    # display(p)
    return p
end

plot_tail_fraction_vs_N(results)

# %%
function plot_fidelity_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # Linear scale is better for Fidelity since it's close to 1
    p = plot(title="Spectral Fidelity vs N", xlabel="System Size (N)", ylabel="Fidelity (F)",
             legend=:bottomleft, grid=true, bg_legend=:transparent,
             ylims=(0.9999995, 1.00)) # Zoom in near 1.0
    
    for σ in unique_sigmas
        data = filter(d -> d["σ"] == σ, results)
        sort!(data, by = d -> d["N"])
        x = Float64[d["N"] for d in data]; y = Float64[d["fidelity"] for d in data]
        
        plot!(p, x, y, label="σ=$σ", marker=:diamond, lw=2)
    end
    return p
end

plot_fidelity_vs_N(results)

# %%
function plot_observable_error_vs_N(results::Vector{Dict{String, Any}})
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    # Linear scale is better for Fidelity since it's close to 1
    p = plot(title="Observable Bound vs N", xlabel="System Size (N)", ylabel="Observable Bound",
             legend=:topright, grid=true, bg_legend=:transparent)
    
    for σ in unique_sigmas
        data = filter(d -> d["σ"] == σ, results)
        sort!(data, by = d -> d["N"])
        x = Float64[d["N"] for d in data]; y = Float64[d["observable_bound"] for d in data]
        
        plot!(p, x, y, label="σ=$σ", marker=:diamond, lw=2)
    end
    return p
end

plot_observable_error_vs_N(results)

# %%
using Pkg
Pkg.add(["LinearAlgebra", "ITensors", "ITensorMPS", "Statistics", "JLD2", "FileIO"])

using LinearAlgebra
using ITensors
using ITensorMPS
using Statistics
using JLD2, FileIO

function generate_fully_connected_wam(N::Int, σ::Float64; μ::Float64=1.0)
    """
    Create a weighted adjacency matrix for a fully connected graph of N nodes. μ should always be one really.
    """
 
    A = zeros(Float64, N, N)
    for i in 1:N
        for j in (i+1):N
            weight = μ + σ * randn() # weight from normal distribution with mean μ and std σ
            A[i, j] = weight
            A[j, i] = weight 
        end
    end
    return A
end 

function create_xxz_hamiltonian_mpo(N, adj_mat, J, Δ, sites)
    """Create the XXZ Hamiltonian as an MPO given an adjacency matrix."""
    ampo = OpSum()
    for i = 1:N-1
        for j = i+1:N
            weight = adj_mat[i, j]
            if weight != 0.0
                # XX and YY terms: S+S- + S-S+ = 2(SxSx + SySy)
                # So to get J(SxSx + SySy), we need J/2 * (S+S- + S-S+)
                ampo += weight * J/2, "S+", i, "S-", j
                ampo += weight * J/2, "S-", i, "S+", j
                # ZZ term
                ampo += weight * J * Δ, "Sz", i, "Sz", j
            end
        end
    end
    H = MPO(ampo, sites)
    return H
end 

function solve_xxz_hamiltonian_dmrg(H, ψ0, sweeps::Int=10, bond_dim::Int=1000, cutoff::Float64=1E-14)
    """Solves the XXZ Hamiltonian using DMRG with given parameters. Returns the ground state energy and MPS. """
    swps = Sweeps(sweeps)
    setmaxdim!(swps, bond_dim)
    setcutoff!(swps, cutoff)
    E, ψ = dmrg(H, ψ0, swps; outputlevel=0)
    return E, ψ # only ground state and ground state wavefunction
end

function create_MPS(L::Int, conserve_qns::Bool=true)
    """Create a random MPS for a spin-1/2 chain of length L with bond dimension Χ."""
    # create a site set for a spin-1/2 chain
    sites = siteinds("S=1/2", L; conserve_qns=conserve_qns) # conserve total Sz

    # create a random MPS with bond dimension Χ
    init_state = [isodd(i) ? "Up" : "Dn" for i = 1:L] # antiferromagnetic ground state
    # THIS IS IMPORTANT - SEE NOTE BELOW
    # it sets the subspace of states we are allowed to explore
    # for example, this init_state means we only explore states with total Sz = 0 (i.e. zero magnetisation)
    # this is a reasonable assumption for positive J, but not for negative J
    # if we want to explore ferromagnetic states (negative J), we would need a different init_state
    # USE create_custom_MPS TO SET A DIFFERENT INIT STATE
    ψ0 = MPS(sites, init_state)
    return ψ0, sites
end

function find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    ψ_mps_N, sites_N = create_MPS(N)
    wam_N = generate_fully_connected_wam(N, σ; μ)
    H_N = create_xxz_hamiltonian_mpo(N, wam_N, J, Δ, sites_N)
    _, ψ_gs_N = solve_xxz_hamiltonian_dmrg(H_N, ψ_mps_N, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    return ψ_gs_N
end

function get_entanglement_data(psi, b)
    orthogonalize!(psi, b)
    s = siteind(psi, b)
    
    local U, S, V
    if b==1
        # no link to left, edge case
        U, S, V = svd(psi[b], (s,))
    else
        l = linkind(psi, b-1)
        U, S, V = svd(psi[b], (l, s))
    end

    schmidt_coefs = diag(S)
    schmidt_spectrum = schmidt_coefs .^ 2 # square all schmidt_coefs
    schmidt_spectrum = schmidt_spectrum[schmidt_spectrum .> 1e-20] # filter out really small p so we don't get NaN entropies
    schmidt_spectrum ./= sum(schmidt_spectrum) # normalise

    vn_entropy = -sum(p * log(p) for p in schmidt_spectrum) # von neuman entropy

    return schmidt_coefs, vn_entropy
end

function sort_spectrum(run_coefs)
    spectrum = run_coefs .^ 2
    # spectrum = spectrum[spectrum .> 1e-15]
    spectrum ./= sum(spectrum)
    
    sorted_indices = sortperm(spectrum, rev=true)
    sorted_spec = spectrum[sorted_indices]
    return sorted_spec
end

function get_bipartite_sorted_spectrum(gs_mps)
    b = ceil(Int, N / 2) # bipartite cut
    schmidt_coefs, _ = get_entanglement_data(gs_mps, b)
    return sort_spectrum(schmidt_coefs)
end
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
# sort_spectrum (generic function with 1 method)

# %%
J = Δ = -1
μ = 1.0

NUM_SWEEPS = 30
MAX_BOND_DIM = typemax(Int) # as high as ram allows
ACC = eps(Float64) # machine precision
# Out:
# 2.220446049250313e-16

# %%
function find_approximation_MPS(N, σ, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)

    # first get mps ground state for this system
    # find deviation index k 
    # then find approximable state by limiting max bond dim to k
    
    # first do for sigma=0
    println("Finding ground state MPS states...")
    gs_mps_0 = find_ground_state_mps(N, J, Δ, 0.0, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    gs_mps_σ = find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
    println("Found ground state MPS states.")

    # then find the deviation between these. We need the sorted Schmidt coefficients
    println("Finding Schmidt spectrums...")
    b = ceil(Int, N / 2) # bipartite cut
    schmidt_coefs_0, vn_entropy_0 = get_entanglement_data(gs_mps_0, b)
    schmidt_coefs_σ, vn_entropy_σ = get_entanglement_data(gs_mps_σ, b)
    sorted_spec_0 = sort_spectrum(schmidt_coefs_0)
    sorted_spec_σ = sort_spectrum(schmidt_coefs_σ)
    println("Found Schmidt spectrums.")

    # find deviated index

    println("Finding deviation index...")
    dev_idx = find_tail_divergence(sorted_spec_0, sorted_spec_σ)
    println("Found deviation index $dev_idx.")

    # approximable state is then the disordered state run with max bond dim as the dev index
    println("Finding approximate MPS ground state...")
    appx_gs_mps = find_ground_state_mps(N, J, Δ, σ, μ, NUM_SWEEPS, dev_idx, ACC)
    appx_bond_dim = maxlinkdim(appx_gs_mps)
    println("Found approximate MPS ground state with bond dimension $appx_bond_dim.")

    return appx_gs_mps, gs_mps_σ
    
end
# Out:
# find_approximation_MPS (generic function with 1 method)

# %%
apx_mps, actual_mps = find_approximation_MPS(30, 0.002, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)
# Out:
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 16.
# (MPS
# [1] ((dim=2|id=795|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=64|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=624|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=558|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=64|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=263|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=560|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=4|id=624|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=701|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=814|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=8|id=560|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=213|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=6|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 3
#  3: QN("Sz",-1) => 4
#  4: QN("Sz",1) => 4
#  5: QN("Sz",3) => 3
#  6: QN("Sz",5) => 1, (dim=14|id=814|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=874|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=253|"Link,l=6") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 2
#  3: QN("Sz",-2) => 3
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 3
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=16|id=6|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 3
#  3: QN("Sz",-1) => 4
#  4: QN("Sz",1) => 4
#  5: QN("Sz",3) => 3
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=283|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=111|"Link,l=7") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 3
#  4: QN("Sz",-1) => 3
#  5: QN("Sz",1) => 3
#  6: QN("Sz",3) => 3
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=16|id=253|"Link,l=6") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 2
#  3: QN("Sz",-2) => 3
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 3
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [8] ((dim=2|id=140|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=973|"Link,l=8") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 3
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 2
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=16|id=111|"Link,l=7") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 3
#  4: QN("Sz",-1) => 3
#  5: QN("Sz",1) => 3
#  6: QN("Sz",3) => 3
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [9] ((dim=2|id=626|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=238|"Link,l=9") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 2
#  5: QN("Sz",-1) => 3
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 2
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=16|id=973|"Link,l=8") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 3
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 2
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [10] ((dim=2|id=306|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=109|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 2
#  5: QN("Sz",-2) => 2
#  6: QN("Sz",0) => 2
#  7: QN("Sz",2) => 2
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=16|id=238|"Link,l=9") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 2
#  5: QN("Sz",-1) => 3
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 2
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [11] ((dim=2|id=509|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=689|"Link,l=11") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 2
#  6: QN("Sz",-1) => 2
#  7: QN("Sz",1) => 2
#  8: QN("Sz",3) => 2
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=16|id=109|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 2
#  5: QN("Sz",-2) => 2
#  6: QN("Sz",0) => 2
#  7: QN("Sz",2) => 2
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=695|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=306|"Link,l=12") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 2
#  7: QN("Sz",0) => 2
#  8: QN("Sz",2) => 2
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=16|id=689|"Link,l=11") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 2
#  6: QN("Sz",-1) => 2
#  7: QN("Sz",1) => 2
#  8: QN("Sz",3) => 2
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [13] ((dim=2|id=8|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=493|"Link,l=13") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 2
#  8: QN("Sz",1) => 2
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=16|id=306|"Link,l=12") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 2
#  7: QN("Sz",0) => 2
#  8: QN("Sz",2) => 2
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [14] ((dim=2|id=263|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=840|"Link,l=14") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 2
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=16|id=493|"Link,l=13") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 2
#  8: QN("Sz",1) => 2
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [15] ((dim=2|id=36|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=849|"Link,l=15") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",1) => 1
#  10: QN("Sz",3) => 1
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1, (dim=16|id=840|"Link,l=14") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 2
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [16] ((dim=2|id=919|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=412|"Link,l=16") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 2
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=16|id=849|"Link,l=15") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 1
#  6: QN("Sz",-5) => 1
#  7: QN("Sz",-3) => 1
#  8: QN("Sz",-1) => 1
#  9: QN("Sz",1) => 1
#  10: QN("Sz",3) => 1
#  11: QN("Sz",5) => 1
#  12: QN("Sz",7) => 1
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1)
# [17] ((dim=2|id=409|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=240|"Link,l=17") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 2
#  8: QN("Sz",1) => 2
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=16|id=412|"Link,l=16") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 1
#  6: QN("Sz",-4) => 1
#  7: QN("Sz",-2) => 1
#  8: QN("Sz",0) => 2
#  9: QN("Sz",2) => 1
#  10: QN("Sz",4) => 1
#  11: QN("Sz",6) => 1
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [18] ((dim=2|id=431|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=52|"Link,l=18") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 2
#  7: QN("Sz",0) => 2
#  8: QN("Sz",2) => 2
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=16|id=240|"Link,l=17") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 1
#  6: QN("Sz",-3) => 1
#  7: QN("Sz",-1) => 2
#  8: QN("Sz",1) => 2
#  9: QN("Sz",3) => 1
#  10: QN("Sz",5) => 1
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [19] ((dim=2|id=54|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=690|"Link,l=19") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 1
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=16|id=52|"Link,l=18") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 1
#  5: QN("Sz",-4) => 1
#  6: QN("Sz",-2) => 2
#  7: QN("Sz",0) => 2
#  8: QN("Sz",2) => 2
#  9: QN("Sz",4) => 1
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [20] ((dim=2|id=657|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=833|"Link,l=20") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 2
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 2
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=16|id=690|"Link,l=19") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 1
#  5: QN("Sz",-3) => 1
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 1
#  9: QN("Sz",5) => 1
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [21] ((dim=2|id=862|"S=1/2,Site,n=21") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=195|"Link,l=21") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 2
#  5: QN("Sz",-1) => 3
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 2
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=16|id=833|"Link,l=20") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 2
#  6: QN("Sz",0) => 3
#  7: QN("Sz",2) => 2
#  8: QN("Sz",4) => 2
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [22] ((dim=2|id=347|"S=1/2,Site,n=22") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=807|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 3
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 2
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=16|id=195|"Link,l=21") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 2
#  5: QN("Sz",-1) => 3
#  6: QN("Sz",1) => 3
#  7: QN("Sz",3) => 2
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [23] ((dim=2|id=75|"S=1/2,Site,n=23") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=141|"Link,l=23") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 3
#  4: QN("Sz",-1) => 3
#  5: QN("Sz",1) => 3
#  6: QN("Sz",3) => 3
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=16|id=807|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 2
#  4: QN("Sz",-2) => 3
#  5: QN("Sz",0) => 3
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 2
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [24] ((dim=2|id=568|"S=1/2,Site,n=24") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=291|"Link,l=24") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 3
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 3
#  6: QN("Sz",4) => 2
#  7: QN("Sz",6) => 1, (dim=16|id=141|"Link,l=23") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 3
#  4: QN("Sz",-1) => 3
#  5: QN("Sz",1) => 3
#  6: QN("Sz",3) => 3
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [25] ((dim=2|id=862|"S=1/2,Site,n=25") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=45|"Link,l=25") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 3
#  3: QN("Sz",-1) => 4
#  4: QN("Sz",1) => 4
#  5: QN("Sz",3) => 3
#  6: QN("Sz",5) => 1, (dim=16|id=291|"Link,l=24") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 3
#  3: QN("Sz",-2) => 3
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 3
#  6: QN("Sz",4) => 2
#  7: QN("Sz",6) => 1)
# [26] ((dim=2|id=90|"S=1/2,Site,n=26") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=154|"Link,l=26") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=16|id=45|"Link,l=25") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 3
#  3: QN("Sz",-1) => 4
#  4: QN("Sz",1) => 4
#  5: QN("Sz",3) => 3
#  6: QN("Sz",5) => 1)
# [27] ((dim=2|id=156|"S=1/2,Site,n=27") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=197|"Link,l=27") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=14|id=154|"Link,l=26") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [28] ((dim=2|id=792|"S=1/2,Site,n=28") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=230|"Link,l=28") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=197|"Link,l=27") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [29] ((dim=2|id=295|"S=1/2,Site,n=29") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=257|"Link,l=29") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=230|"Link,l=28") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [30] ((dim=2|id=65|"S=1/2,Site,n=30") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=257|"Link,l=29") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , MPS
# [1] ((dim=2|id=366|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=675|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=882|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=675|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=342|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=17|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=342|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=748|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=909|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=748|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=15|id=367|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=435|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=15|id=367|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1, (dim=24|id=547|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 6
#  4: QN("Sz",-1) => 6
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1)
# [6] ((dim=2|id=347|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=547|"Link,l=5") <Out>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 6
#  4: QN("Sz",-1) => 6
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1, (dim=38|id=173|"Link,l=6") <In>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 8
#  4: QN("Sz",0) => 8
#  5: QN("Sz",-2) => 8
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1)
# [7] ((dim=2|id=88|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=38|id=173|"Link,l=6") <Out>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 8
#  4: QN("Sz",0) => 8
#  5: QN("Sz",-2) => 8
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1, (dim=50|id=170|"Link,l=7") <In>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 8
#  4: QN("Sz",1) => 9
#  5: QN("Sz",-1) => 9
#  6: QN("Sz",-3) => 8
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1)
# [8] ((dim=2|id=724|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=50|id=170|"Link,l=7") <Out>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 8
#  4: QN("Sz",1) => 9
#  5: QN("Sz",-1) => 9
#  6: QN("Sz",-3) => 8
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1, (dim=70|id=267|"Link,l=8") <In>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 8
#  4: QN("Sz",2) => 12
#  5: QN("Sz",0) => 12
#  6: QN("Sz",-2) => 12
#  7: QN("Sz",-4) => 8
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1)
# [9] ((dim=2|id=629|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=70|id=267|"Link,l=8") <Out>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 8
#  4: QN("Sz",2) => 12
#  5: QN("Sz",0) => 12
#  6: QN("Sz",-2) => 12
#  7: QN("Sz",-4) => 8
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1, (dim=89|id=784|"Link,l=9") <In>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 12
#  5: QN("Sz",1) => 14
#  6: QN("Sz",-1) => 14
#  7: QN("Sz",-3) => 11
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [10] ((dim=2|id=430|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=89|id=784|"Link,l=9") <Out>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 12
#  5: QN("Sz",1) => 14
#  6: QN("Sz",-1) => 14
#  7: QN("Sz",-3) => 11
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1, (dim=122|id=129|"Link,l=10") <In>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 10
#  3: QN("Sz",6) => 10
#  4: QN("Sz",4) => 14
#  5: QN("Sz",2) => 17
#  6: QN("Sz",0) => 18
#  7: QN("Sz",-2) => 17
#  8: QN("Sz",-4) => 14
#  9: QN("Sz",-6) => 10
#  10: QN("Sz",-8) => 10
#  11: QN("Sz",-10) => 1)
# [11] ((dim=2|id=177|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=122|id=129|"Link,l=10") <Out>
#  1: QN("Sz",10) => 1
#  2: QN("Sz",8) => 10
#  3: QN("Sz",6) => 10
#  4: QN("Sz",4) => 14
#  5: QN("Sz",2) => 17
#  6: QN("Sz",0) => 18
#  7: QN("Sz",-2) => 17
#  8: QN("Sz",-4) => 14
#  9: QN("Sz",-6) => 10
#  10: QN("Sz",-8) => 10
#  11: QN("Sz",-10) => 1, (dim=161|id=938|"Link,l=11") <In>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 11
#  3: QN("Sz",7) => 11
#  4: QN("Sz",5) => 13
#  5: QN("Sz",3) => 22
#  6: QN("Sz",1) => 23
#  7: QN("Sz",-1) => 23
#  8: QN("Sz",-3) => 22
#  9: QN("Sz",-5) => 12
#  10: QN("Sz",-7) => 11
#  11: QN("Sz",-9) => 11
#  12: QN("Sz",-11) => 1)
# [12] ((dim=2|id=990|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=161|id=938|"Link,l=11") <Out>
#  1: QN("Sz",11) => 1
#  2: QN("Sz",9) => 11
#  3: QN("Sz",7) => 11
#  4: QN("Sz",5) => 13
#  5: QN("Sz",3) => 22
#  6: QN("Sz",1) => 23
#  7: QN("Sz",-1) => 23
#  8: QN("Sz",-3) => 22
#  9: QN("Sz",-5) => 12
#  10: QN("Sz",-7) => 11
#  11: QN("Sz",-9) => 11
#  12: QN("Sz",-11) => 1, (dim=195|id=420|"Link,l=12") <In>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 12
#  3: QN("Sz",8) => 12
#  4: QN("Sz",6) => 12
#  5: QN("Sz",4) => 21
#  6: QN("Sz",2) => 26
#  7: QN("Sz",0) => 27
#  8: QN("Sz",-2) => 26
#  9: QN("Sz",-4) => 21
#  10: QN("Sz",-6) => 12
#  11: QN("Sz",-8) => 12
#  12: QN("Sz",-10) => 12
#  13: QN("Sz",-12) => 1)
# [13] ((dim=2|id=995|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=195|id=420|"Link,l=12") <Out>
#  1: QN("Sz",12) => 1
#  2: QN("Sz",10) => 12
#  3: QN("Sz",8) => 12
#  4: QN("Sz",6) => 12
#  5: QN("Sz",4) => 21
#  6: QN("Sz",2) => 26
#  7: QN("Sz",0) => 27
#  8: QN("Sz",-2) => 26
#  9: QN("Sz",-4) => 21
#  10: QN("Sz",-6) => 12
#  11: QN("Sz",-8) => 12
#  12: QN("Sz",-10) => 12
#  13: QN("Sz",-12) => 1, (dim=235|id=393|"Link,l=13") <In>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 13
#  3: QN("Sz",9) => 13
#  4: QN("Sz",7) => 13
#  5: QN("Sz",5) => 20
#  6: QN("Sz",3) => 28
#  7: QN("Sz",1) => 30
#  8: QN("Sz",-1) => 30
#  9: QN("Sz",-3) => 28
#  10: QN("Sz",-5) => 19
#  11: QN("Sz",-7) => 13
#  12: QN("Sz",-9) => 13
#  13: QN("Sz",-11) => 13
#  14: QN("Sz",-13) => 1)
# [14] ((dim=2|id=598|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=235|id=393|"Link,l=13") <Out>
#  1: QN("Sz",13) => 1
#  2: QN("Sz",11) => 13
#  3: QN("Sz",9) => 13
#  4: QN("Sz",7) => 13
#  5: QN("Sz",5) => 20
#  6: QN("Sz",3) => 28
#  7: QN("Sz",1) => 30
#  8: QN("Sz",-1) => 30
#  9: QN("Sz",-3) => 28
#  10: QN("Sz",-5) => 19
#  11: QN("Sz",-7) => 13
#  12: QN("Sz",-9) => 13
#  13: QN("Sz",-11) => 13
#  14: QN("Sz",-13) => 1, (dim=272|id=839|"Link,l=14") <In>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 14
#  3: QN("Sz",10) => 14
#  4: QN("Sz",8) => 14
#  5: QN("Sz",6) => 15
#  6: QN("Sz",4) => 27
#  7: QN("Sz",2) => 33
#  8: QN("Sz",0) => 36
#  9: QN("Sz",-2) => 33
#  10: QN("Sz",-4) => 27
#  11: QN("Sz",-6) => 15
#  12: QN("Sz",-8) => 14
#  13: QN("Sz",-10) => 14
#  14: QN("Sz",-12) => 14
#  15: QN("Sz",-14) => 1)
# [15] ((dim=2|id=896|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=301|id=470|"Link,l=15") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 14
#  3: QN("Sz",-11) => 14
#  4: QN("Sz",-9) => 15
#  5: QN("Sz",-7) => 15
#  6: QN("Sz",-5) => 23
#  7: QN("Sz",-3) => 33
#  8: QN("Sz",-1) => 36
#  9: QN("Sz",1) => 36
#  10: QN("Sz",3) => 33
#  11: QN("Sz",5) => 22
#  12: QN("Sz",7) => 15
#  13: QN("Sz",9) => 15
#  14: QN("Sz",11) => 14
#  15: QN("Sz",13) => 14
#  16: QN("Sz",15) => 1, (dim=272|id=839|"Link,l=14") <Out>
#  1: QN("Sz",14) => 1
#  2: QN("Sz",12) => 14
#  3: QN("Sz",10) => 14
#  4: QN("Sz",8) => 14
#  5: QN("Sz",6) => 15
#  6: QN("Sz",4) => 27
#  7: QN("Sz",2) => 33
#  8: QN("Sz",0) => 36
#  9: QN("Sz",-2) => 33
#  10: QN("Sz",-4) => 27
#  11: QN("Sz",-6) => 15
#  12: QN("Sz",-8) => 14
#  13: QN("Sz",-10) => 14
#  14: QN("Sz",-12) => 14
#  15: QN("Sz",-14) => 1)
# [16] ((dim=2|id=263|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=269|id=242|"Link,l=16") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 14
#  3: QN("Sz",-10) => 14
#  4: QN("Sz",-8) => 14
#  5: QN("Sz",-6) => 16
#  6: QN("Sz",-4) => 26
#  7: QN("Sz",-2) => 33
#  8: QN("Sz",0) => 34
#  9: QN("Sz",2) => 33
#  10: QN("Sz",4) => 25
#  11: QN("Sz",6) => 16
#  12: QN("Sz",8) => 14
#  13: QN("Sz",10) => 14
#  14: QN("Sz",12) => 14
#  15: QN("Sz",14) => 1, (dim=301|id=470|"Link,l=15") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 14
#  3: QN("Sz",-11) => 14
#  4: QN("Sz",-9) => 15
#  5: QN("Sz",-7) => 15
#  6: QN("Sz",-5) => 23
#  7: QN("Sz",-3) => 33
#  8: QN("Sz",-1) => 36
#  9: QN("Sz",1) => 36
#  10: QN("Sz",3) => 33
#  11: QN("Sz",5) => 22
#  12: QN("Sz",7) => 15
#  13: QN("Sz",9) => 15
#  14: QN("Sz",11) => 14
#  15: QN("Sz",13) => 14
#  16: QN("Sz",15) => 1)
# [17] ((dim=2|id=613|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=219|id=34|"Link,l=17") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 13
#  3: QN("Sz",-9) => 13
#  4: QN("Sz",-7) => 13
#  5: QN("Sz",-5) => 17
#  6: QN("Sz",-3) => 25
#  7: QN("Sz",-1) => 27
#  8: QN("Sz",1) => 27
#  9: QN("Sz",3) => 26
#  10: QN("Sz",5) => 17
#  11: QN("Sz",7) => 13
#  12: QN("Sz",9) => 13
#  13: QN("Sz",11) => 13
#  14: QN("Sz",13) => 1, (dim=269|id=242|"Link,l=16") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 14
#  3: QN("Sz",-10) => 14
#  4: QN("Sz",-8) => 14
#  5: QN("Sz",-6) => 16
#  6: QN("Sz",-4) => 26
#  7: QN("Sz",-2) => 33
#  8: QN("Sz",0) => 34
#  9: QN("Sz",2) => 33
#  10: QN("Sz",4) => 25
#  11: QN("Sz",6) => 16
#  12: QN("Sz",8) => 14
#  13: QN("Sz",10) => 14
#  14: QN("Sz",12) => 14
#  15: QN("Sz",14) => 1)
# [18] ((dim=2|id=915|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=164|id=85|"Link,l=18") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 12
#  3: QN("Sz",-8) => 12
#  4: QN("Sz",-6) => 12
#  5: QN("Sz",-4) => 15
#  6: QN("Sz",-2) => 20
#  7: QN("Sz",0) => 21
#  8: QN("Sz",2) => 20
#  9: QN("Sz",4) => 14
#  10: QN("Sz",6) => 12
#  11: QN("Sz",8) => 12
#  12: QN("Sz",10) => 12
#  13: QN("Sz",12) => 1, (dim=219|id=34|"Link,l=17") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 13
#  3: QN("Sz",-9) => 13
#  4: QN("Sz",-7) => 13
#  5: QN("Sz",-5) => 17
#  6: QN("Sz",-3) => 25
#  7: QN("Sz",-1) => 27
#  8: QN("Sz",1) => 27
#  9: QN("Sz",3) => 26
#  10: QN("Sz",5) => 17
#  11: QN("Sz",7) => 13
#  12: QN("Sz",9) => 13
#  13: QN("Sz",11) => 13
#  14: QN("Sz",13) => 1)
# [19] ((dim=2|id=659|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=138|id=353|"Link,l=19") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 11
#  3: QN("Sz",-7) => 11
#  4: QN("Sz",-5) => 11
#  5: QN("Sz",-3) => 16
#  6: QN("Sz",-1) => 19
#  7: QN("Sz",1) => 19
#  8: QN("Sz",3) => 16
#  9: QN("Sz",5) => 11
#  10: QN("Sz",7) => 11
#  11: QN("Sz",9) => 11
#  12: QN("Sz",11) => 1, (dim=164|id=85|"Link,l=18") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 12
#  3: QN("Sz",-8) => 12
#  4: QN("Sz",-6) => 12
#  5: QN("Sz",-4) => 15
#  6: QN("Sz",-2) => 20
#  7: QN("Sz",0) => 21
#  8: QN("Sz",2) => 20
#  9: QN("Sz",4) => 14
#  10: QN("Sz",6) => 12
#  11: QN("Sz",8) => 12
#  12: QN("Sz",10) => 12
#  13: QN("Sz",12) => 1)
# [20] ((dim=2|id=607|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=119|id=61|"Link,l=20") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 13
#  5: QN("Sz",-2) => 17
#  6: QN("Sz",0) => 17
#  7: QN("Sz",2) => 17
#  8: QN("Sz",4) => 13
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1, (dim=138|id=353|"Link,l=19") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 11
#  3: QN("Sz",-7) => 11
#  4: QN("Sz",-5) => 11
#  5: QN("Sz",-3) => 16
#  6: QN("Sz",-1) => 19
#  7: QN("Sz",1) => 19
#  8: QN("Sz",3) => 16
#  9: QN("Sz",5) => 11
#  10: QN("Sz",7) => 11
#  11: QN("Sz",9) => 11
#  12: QN("Sz",11) => 1)
# [21] ((dim=2|id=128|"S=1/2,Site,n=21") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=88|id=690|"Link,l=21") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 9
#  4: QN("Sz",-3) => 11
#  5: QN("Sz",-1) => 14
#  6: QN("Sz",1) => 14
#  7: QN("Sz",3) => 11
#  8: QN("Sz",5) => 9
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1, (dim=119|id=61|"Link,l=20") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 13
#  5: QN("Sz",-2) => 17
#  6: QN("Sz",0) => 17
#  7: QN("Sz",2) => 17
#  8: QN("Sz",4) => 13
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1)
# [22] ((dim=2|id=838|"S=1/2,Site,n=22") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=71|id=599|"Link,l=22") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 8
#  4: QN("Sz",-2) => 12
#  5: QN("Sz",0) => 13
#  6: QN("Sz",2) => 12
#  7: QN("Sz",4) => 8
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1, (dim=88|id=690|"Link,l=21") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 9
#  4: QN("Sz",-3) => 11
#  5: QN("Sz",-1) => 14
#  6: QN("Sz",1) => 14
#  7: QN("Sz",3) => 11
#  8: QN("Sz",5) => 9
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1)
# [23] ((dim=2|id=662|"S=1/2,Site,n=23") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=55|id=621|"Link,l=23") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 9
#  4: QN("Sz",-1) => 11
#  5: QN("Sz",1) => 11
#  6: QN("Sz",3) => 8
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1, (dim=71|id=599|"Link,l=22") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 8
#  4: QN("Sz",-2) => 12
#  5: QN("Sz",0) => 13
#  6: QN("Sz",2) => 12
#  7: QN("Sz",4) => 8
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1)
# [24] ((dim=2|id=92|"S=1/2,Site,n=24") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=35|id=746|"Link,l=24") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 7
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 7
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=55|id=621|"Link,l=23") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 9
#  4: QN("Sz",-1) => 11
#  5: QN("Sz",1) => 11
#  6: QN("Sz",3) => 8
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1)
# [25] ((dim=2|id=344|"S=1/2,Site,n=25") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=25|id=144|"Link,l=25") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 7
#  4: QN("Sz",1) => 6
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=35|id=746|"Link,l=24") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 7
#  4: QN("Sz",0) => 7
#  5: QN("Sz",2) => 7
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [26] ((dim=2|id=832|"S=1/2,Site,n=26") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=15|id=884|"Link,l=26") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=25|id=144|"Link,l=25") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 7
#  4: QN("Sz",1) => 6
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [27] ((dim=2|id=38|"S=1/2,Site,n=27") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=551|"Link,l=27") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=15|id=884|"Link,l=26") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [28] ((dim=2|id=606|"S=1/2,Site,n=28") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=738|"Link,l=28") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=551|"Link,l=27") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [29] ((dim=2|id=642|"S=1/2,Site,n=29") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=95|"Link,l=29") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=738|"Link,l=28") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [30] ((dim=2|id=6|"S=1/2,Site,n=30") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=95|"Link,l=29") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# )

# %%
function appx_results(N_vals, σ_vals)
    results = Vector{Dict{String, Any}}()

    for N in N_vals
        for σ in σ_vals
            println("N=$N, σ=$σ")
            apx, act = find_approximation_MPS(N, σ, J, Δ, μ, NUM_SWEEPS, MAX_BOND_DIM, ACC)

            results_dict = Dict(
                "N" => N,
                "σ" => σ,
                "apx" => apx,
                "act" => act
            )

            push!(results, results_dict)
            
        end # σ loop
    end # N loop

    return results
end

N_vals = 10:10:60
appx_result = appx_results(N_vals, [0.001, 0.002])
# Out:
# N=10, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 6.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 6.
# N=10, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 6.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 6.
# N=20, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 11.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 11.
# N=20, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 11.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 11.
# N=30, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 16.
# N=30, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 16.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 16.
# N=40, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 20.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 20.
# N=40, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 20.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 20.
# N=50, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 23.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 23.
# N=50, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 21.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 21.
# N=60, σ=0.001
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 24.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 24.
# N=60, σ=0.002
# Finding ground state MPS states...
# Found ground state MPS states.
# Finding Schmidt spectrums...
# Found Schmidt spectrums.
# Finding deviation index...
# Found deviation index 24.
# Finding approximate MPS ground state...
# Found approximate MPS ground state with bond dimension 24.
# 12-element Vector{Dict{String, Any}}:
#  Dict("act" => MPS
# [1] ((dim=2|id=847|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=515|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=982|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=515|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=378|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=509|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=378|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=564|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=701|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=564|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=15|id=210|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=693|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=26|id=930|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 7
#  4: QN("Sz",1) => 7
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=15|id=210|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 5
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [6] ((dim=2|id=617|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=136|"Link,l=6") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=26|id=930|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 7
#  4: QN("Sz",1) => 7
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=602|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=978|"Link,l=7") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=16|id=136|"Link,l=6") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [8] ((dim=2|id=491|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=230|"Link,l=8") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=978|"Link,l=7") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [9] ((dim=2|id=718|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=822|"Link,l=9") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=230|"Link,l=8") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [10] ((dim=2|id=201|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=822|"Link,l=9") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "apx" => MPS
# [1] ((dim=2|id=153|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=336|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=236|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=802|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=336|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=919|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=906|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1, (dim=4|id=236|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=243|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=126|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1, (dim=6|id=906|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=521|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=52|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1, (dim=6|id=126|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=73|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=157|"Link,l=6") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1, (dim=6|id=52|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=870|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=442|"Link,l=7") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1, (dim=6|id=157|"Link,l=6") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1)
# [8] ((dim=2|id=773|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=859|"Link,l=8") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=6|id=442|"Link,l=7") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1)
# [9] ((dim=2|id=529|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=581|"Link,l=9") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=859|"Link,l=8") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [10] ((dim=2|id=957|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=581|"Link,l=9") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "N" => 10, "σ" => 0.001)
#  Dict("act" => MPS
# [1] ((dim=2|id=383|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=169|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=288|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=169|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=273|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=639|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=273|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=974|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=405|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=974|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=16|id=269|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=531|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=30|id=734|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 9
#  4: QN("Sz",1) => 9
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=16|id=269|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [6] ((dim=2|id=194|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=7|"Link,l=6") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=30|id=734|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 9
#  4: QN("Sz",1) => 9
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=468|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=392|"Link,l=7") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=16|id=7|"Link,l=6") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [8] ((dim=2|id=546|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=724|"Link,l=8") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=392|"Link,l=7") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [9] ((dim=2|id=744|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=194|"Link,l=9") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=724|"Link,l=8") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [10] ((dim=2|id=938|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=194|"Link,l=9") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "apx" => MPS
# [1] ((dim=2|id=191|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=16|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=809|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=561|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=16|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=978|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=537|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1, (dim=4|id=809|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=233|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=118|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1, (dim=6|id=537|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=480|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=367|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1, (dim=6|id=118|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=107|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=166|"Link,l=6") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1, (dim=6|id=367|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 1
#  3: QN("Sz",-1) => 1
#  4: QN("Sz",1) => 1
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=133|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=6|id=743|"Link,l=7") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1, (dim=6|id=166|"Link,l=6") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 1
#  3: QN("Sz",0) => 2
#  4: QN("Sz",2) => 1
#  5: QN("Sz",4) => 1)
# [8] ((dim=2|id=354|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=103|"Link,l=8") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=6|id=743|"Link,l=7") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 2
#  3: QN("Sz",1) => 2
#  4: QN("Sz",3) => 1)
# [9] ((dim=2|id=853|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=775|"Link,l=9") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=103|"Link,l=8") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [10] ((dim=2|id=636|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=775|"Link,l=9") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "N" => 10, "σ" => 0.002)
#  Dict("act" => MPS
# [1] ((dim=2|id=355|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=464|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=740|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=464|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=780|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=480|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=780|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=913|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=825|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=913|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=14|id=36|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=367|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=36|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1, (dim=22|id=292|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 5
#  4: QN("Sz",-1) => 5
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1)
# [6] ((dim=2|id=64|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=22|id=292|"Link,l=5") <Out>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 5
#  4: QN("Sz",-1) => 5
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1, (dim=32|id=638|"Link,l=6") <In>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 6
#  4: QN("Sz",0) => 6
#  5: QN("Sz",-2) => 6
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1)
# [7] ((dim=2|id=192|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=32|id=638|"Link,l=6") <Out>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 6
#  4: QN("Sz",0) => 6
#  5: QN("Sz",-2) => 6
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1, (dim=44|id=883|"Link,l=7") <In>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 7
#  4: QN("Sz",1) => 7
#  5: QN("Sz",-1) => 7
#  6: QN("Sz",-3) => 7
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1)
# [8] ((dim=2|id=411|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=44|id=883|"Link,l=7") <Out>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 7
#  4: QN("Sz",1) => 7
#  5: QN("Sz",-1) => 7
#  6: QN("Sz",-3) => 7
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1, (dim=58|id=564|"Link,l=8") <In>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 8
#  4: QN("Sz",2) => 8
#  5: QN("Sz",0) => 8
#  6: QN("Sz",-2) => 8
#  7: QN("Sz",-4) => 8
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1)
# [9] ((dim=2|id=748|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=58|id=564|"Link,l=8") <Out>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 8
#  4: QN("Sz",2) => 8
#  5: QN("Sz",0) => 8
#  6: QN("Sz",-2) => 8
#  7: QN("Sz",-4) => 8
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1, (dim=74|id=347|"Link,l=9") <In>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 9
#  5: QN("Sz",1) => 9
#  6: QN("Sz",-1) => 9
#  7: QN("Sz",-3) => 9
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [10] ((dim=2|id=281|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=92|id=981|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 10
#  5: QN("Sz",-2) => 10
#  6: QN("Sz",0) => 10
#  7: QN("Sz",2) => 10
#  8: QN("Sz",4) => 10
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1, (dim=74|id=347|"Link,l=9") <Out>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 9
#  4: QN("Sz",3) => 9
#  5: QN("Sz",1) => 9
#  6: QN("Sz",-1) => 9
#  7: QN("Sz",-3) => 9
#  8: QN("Sz",-5) => 9
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [11] ((dim=2|id=611|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=74|id=191|"Link,l=11") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 9
#  4: QN("Sz",-3) => 9
#  5: QN("Sz",-1) => 9
#  6: QN("Sz",1) => 9
#  7: QN("Sz",3) => 9
#  8: QN("Sz",5) => 9
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1, (dim=92|id=981|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 10
#  5: QN("Sz",-2) => 10
#  6: QN("Sz",0) => 10
#  7: QN("Sz",2) => 10
#  8: QN("Sz",4) => 10
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=686|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=58|id=917|"Link,l=12") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 8
#  4: QN("Sz",-2) => 8
#  5: QN("Sz",0) => 8
#  6: QN("Sz",2) => 8
#  7: QN("Sz",4) => 8
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1, (dim=74|id=191|"Link,l=11") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 9
#  4: QN("Sz",-3) => 9
#  5: QN("Sz",-1) => 9
#  6: QN("Sz",1) => 9
#  7: QN("Sz",3) => 9
#  8: QN("Sz",5) => 9
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1)
# [13] ((dim=2|id=191|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=44|id=837|"Link,l=13") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 7
#  4: QN("Sz",-1) => 7
#  5: QN("Sz",1) => 7
#  6: QN("Sz",3) => 7
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1, (dim=58|id=917|"Link,l=12") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 8
#  4: QN("Sz",-2) => 8
#  5: QN("Sz",0) => 8
#  6: QN("Sz",2) => 8
#  7: QN("Sz",4) => 8
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1)
# [14] ((dim=2|id=740|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=32|id=555|"Link,l=14") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 6
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=44|id=837|"Link,l=13") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 7
#  4: QN("Sz",-1) => 7
#  5: QN("Sz",1) => 7
#  6: QN("Sz",3) => 7
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1)
# [15] ((dim=2|id=482|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=22|id=753|"Link,l=15") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=32|id=555|"Link,l=14") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 6
#  4: QN("Sz",0) => 6
#  5: QN("Sz",2) => 6
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [16] ((dim=2|id=454|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=793|"Link,l=16") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=22|id=753|"Link,l=15") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [17] ((dim=2|id=762|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=801|"Link,l=17") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=14|id=793|"Link,l=16") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [18] ((dim=2|id=981|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=53|"Link,l=18") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=801|"Link,l=17") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [19] ((dim=2|id=615|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=768|"Link,l=19") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=53|"Link,l=18") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [20] ((dim=2|id=952|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=768|"Link,l=19") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "apx" => MPS
# [1] ((dim=2|id=857|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=648|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=83|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=390|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=648|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=63|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=232|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=4|id=83|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=949|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=833|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1, (dim=8|id=232|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=979|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=588|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1, (dim=11|id=833|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=831|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=877|"Link,l=6") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1, (dim=11|id=588|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=635|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=517|"Link,l=7") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=11|id=877|"Link,l=6") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1)
# [8] ((dim=2|id=882|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=863|"Link,l=8") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 2
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=11|id=517|"Link,l=7") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [9] ((dim=2|id=347|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=669|"Link,l=9") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 2
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=11|id=863|"Link,l=8") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 2
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [10] ((dim=2|id=269|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=878|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=11|id=669|"Link,l=9") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 2
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [11] ((dim=2|id=552|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=21|"Link,l=11") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 2
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=11|id=878|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=576|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=404|"Link,l=12") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=11|id=21|"Link,l=11") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 2
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [13] ((dim=2|id=671|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=83|"Link,l=13") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=11|id=404|"Link,l=12") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [14] ((dim=2|id=807|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=106|"Link,l=14") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 2
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 2
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1, (dim=11|id=83|"Link,l=13") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [15] ((dim=2|id=927|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=603|"Link,l=15") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 2
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 2
#  6: QN("Sz",5) => 1, (dim=11|id=106|"Link,l=14") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 2
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 2
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1)
# [16] ((dim=2|id=381|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=668|"Link,l=16") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 3
#  5: QN("Sz",4) => 1, (dim=11|id=603|"Link,l=15") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 2
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 2
#  6: QN("Sz",5) => 1)
# [17] ((dim=2|id=395|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=470|"Link,l=17") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=11|id=668|"Link,l=16") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 3
#  5: QN("Sz",4) => 1)
# [18] ((dim=2|id=53|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=966|"Link,l=18") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=470|"Link,l=17") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [19] ((dim=2|id=773|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=847|"Link,l=19") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=966|"Link,l=18") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [20] ((dim=2|id=472|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=847|"Link,l=19") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "N" => 20, "σ" => 0.001)
#  Dict("act" => MPS
# [1] ((dim=2|id=230|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=40|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=875|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=40|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=933|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=38|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=933|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=532|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=296|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=532|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=16|id=53|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=589|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=53|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1, (dim=31|id=634|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 9
#  4: QN("Sz",-1) => 10
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1)
# [6] ((dim=2|id=872|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=31|id=634|"Link,l=5") <Out>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
#  3: QN("Sz",1) => 9
#  4: QN("Sz",-1) => 10
#  5: QN("Sz",-3) => 5
#  6: QN("Sz",-5) => 1, (dim=54|id=536|"Link,l=6") <In>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",-2) => 13
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1)
# [7] ((dim=2|id=914|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=54|id=536|"Link,l=6") <Out>
#  1: QN("Sz",6) => 1
#  2: QN("Sz",4) => 6
#  3: QN("Sz",2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",-2) => 13
#  6: QN("Sz",-4) => 6
#  7: QN("Sz",-6) => 1, (dim=87|id=461|"Link,l=7") <In>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 15
#  4: QN("Sz",1) => 20
#  5: QN("Sz",-1) => 20
#  6: QN("Sz",-3) => 16
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1)
# [8] ((dim=2|id=96|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=87|id=461|"Link,l=7") <Out>
#  1: QN("Sz",7) => 1
#  2: QN("Sz",5) => 7
#  3: QN("Sz",3) => 15
#  4: QN("Sz",1) => 20
#  5: QN("Sz",-1) => 20
#  6: QN("Sz",-3) => 16
#  7: QN("Sz",-5) => 7
#  8: QN("Sz",-7) => 1, (dim=121|id=613|"Link,l=8") <In>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 15
#  4: QN("Sz",2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",-2) => 24
#  7: QN("Sz",-4) => 15
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1)
# [9] ((dim=2|id=439|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=121|id=613|"Link,l=8") <Out>
#  1: QN("Sz",8) => 1
#  2: QN("Sz",6) => 8
#  3: QN("Sz",4) => 15
#  4: QN("Sz",2) => 24
#  5: QN("Sz",0) => 25
#  6: QN("Sz",-2) => 24
#  7: QN("Sz",-4) => 15
#  8: QN("Sz",-6) => 8
#  9: QN("Sz",-8) => 1, (dim=152|id=283|"Link,l=9") <In>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 11
#  4: QN("Sz",3) => 25
#  5: QN("Sz",1) => 30
#  6: QN("Sz",-1) => 30
#  7: QN("Sz",-3) => 25
#  8: QN("Sz",-5) => 11
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [10] ((dim=2|id=112|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=168|id=271|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 20
#  5: QN("Sz",-2) => 28
#  6: QN("Sz",0) => 30
#  7: QN("Sz",2) => 28
#  8: QN("Sz",4) => 20
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1, (dim=152|id=283|"Link,l=9") <Out>
#  1: QN("Sz",9) => 1
#  2: QN("Sz",7) => 9
#  3: QN("Sz",5) => 11
#  4: QN("Sz",3) => 25
#  5: QN("Sz",1) => 30
#  6: QN("Sz",-1) => 30
#  7: QN("Sz",-3) => 25
#  8: QN("Sz",-5) => 11
#  9: QN("Sz",-7) => 9
#  10: QN("Sz",-9) => 1)
# [11] ((dim=2|id=250|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=144|id=560|"Link,l=11") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 12
#  4: QN("Sz",-3) => 23
#  5: QN("Sz",-1) => 27
#  6: QN("Sz",1) => 27
#  7: QN("Sz",3) => 23
#  8: QN("Sz",5) => 12
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1, (dim=168|id=271|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 10
#  3: QN("Sz",-6) => 10
#  4: QN("Sz",-4) => 20
#  5: QN("Sz",-2) => 28
#  6: QN("Sz",0) => 30
#  7: QN("Sz",2) => 28
#  8: QN("Sz",4) => 20
#  9: QN("Sz",6) => 10
#  10: QN("Sz",8) => 10
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=644|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=112|id=981|"Link,l=12") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 21
#  5: QN("Sz",0) => 22
#  6: QN("Sz",2) => 21
#  7: QN("Sz",4) => 15
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1, (dim=144|id=560|"Link,l=11") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 9
#  3: QN("Sz",-5) => 12
#  4: QN("Sz",-3) => 23
#  5: QN("Sz",-1) => 27
#  6: QN("Sz",1) => 27
#  7: QN("Sz",3) => 23
#  8: QN("Sz",5) => 12
#  9: QN("Sz",7) => 9
#  10: QN("Sz",9) => 1)
# [13] ((dim=2|id=929|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=79|id=785|"Link,l=13") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 14
#  4: QN("Sz",-1) => 18
#  5: QN("Sz",1) => 17
#  6: QN("Sz",3) => 14
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1, (dim=112|id=981|"Link,l=12") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 8
#  3: QN("Sz",-4) => 15
#  4: QN("Sz",-2) => 21
#  5: QN("Sz",0) => 22
#  6: QN("Sz",2) => 21
#  7: QN("Sz",4) => 15
#  8: QN("Sz",6) => 8
#  9: QN("Sz",8) => 1)
# [14] ((dim=2|id=63|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=54|id=608|"Link,l=14") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1, (dim=79|id=785|"Link,l=13") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 7
#  3: QN("Sz",-3) => 14
#  4: QN("Sz",-1) => 18
#  5: QN("Sz",1) => 17
#  6: QN("Sz",3) => 14
#  7: QN("Sz",5) => 7
#  8: QN("Sz",7) => 1)
# [15] ((dim=2|id=321|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=31|id=566|"Link,l=15") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 10
#  4: QN("Sz",1) => 9
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=54|id=608|"Link,l=14") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 6
#  3: QN("Sz",-2) => 13
#  4: QN("Sz",0) => 14
#  5: QN("Sz",2) => 13
#  6: QN("Sz",4) => 6
#  7: QN("Sz",6) => 1)
# [16] ((dim=2|id=156|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=16|id=115|"Link,l=16") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=31|id=566|"Link,l=15") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 10
#  4: QN("Sz",1) => 9
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [17] ((dim=2|id=515|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=28|"Link,l=17") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=16|id=115|"Link,l=16") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 6
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [18] ((dim=2|id=848|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=746|"Link,l=18") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=28|"Link,l=17") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [19] ((dim=2|id=782|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=229|"Link,l=19") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=746|"Link,l=18") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [20] ((dim=2|id=596|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=229|"Link,l=19") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "apx" => MPS
# [1] ((dim=2|id=269|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=915|"Link,l=1") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [2] ((dim=4|id=685|"Link,l=2") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=2|id=38|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=915|"Link,l=1") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# [3] ((dim=2|id=400|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=209|"Link,l=3") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=4|id=685|"Link,l=2") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [4] ((dim=2|id=842|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=968|"Link,l=4") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1, (dim=8|id=209|"Link,l=3") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [5] ((dim=2|id=546|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=664|"Link,l=5") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 2
#  5: QN("Sz",3) => 2
#  6: QN("Sz",5) => 1, (dim=11|id=968|"Link,l=4") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 2
#  5: QN("Sz",4) => 1)
# [6] ((dim=2|id=756|"S=1/2,Site,n=6") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=70|"Link,l=6") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1, (dim=11|id=664|"Link,l=5") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 2
#  5: QN("Sz",3) => 2
#  6: QN("Sz",5) => 1)
# [7] ((dim=2|id=366|"S=1/2,Site,n=7") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=492|"Link,l=7") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=11|id=70|"Link,l=6") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1)
# [8] ((dim=2|id=814|"S=1/2,Site,n=8") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=637|"Link,l=8") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 2
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=11|id=492|"Link,l=7") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 2
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 1
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [9] ((dim=2|id=207|"S=1/2,Site,n=9") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=400|"Link,l=9") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 2
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=11|id=637|"Link,l=8") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 2
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 1
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [10] ((dim=2|id=265|"S=1/2,Site,n=10") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=14|"Link,l=10") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=11|id=400|"Link,l=9") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 2
#  6: QN("Sz",1) => 1
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [11] ((dim=2|id=304|"S=1/2,Site,n=11") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=359|"Link,l=11") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 2
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=11|id=14|"Link,l=10") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 1
#  4: QN("Sz",-4) => 1
#  5: QN("Sz",-2) => 1
#  6: QN("Sz",0) => 1
#  7: QN("Sz",2) => 1
#  8: QN("Sz",4) => 1
#  9: QN("Sz",6) => 1
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [12] ((dim=2|id=803|"S=1/2,Site,n=12") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=771|"Link,l=12") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=11|id=359|"Link,l=11") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 1
#  4: QN("Sz",-3) => 1
#  5: QN("Sz",-1) => 1
#  6: QN("Sz",1) => 2
#  7: QN("Sz",3) => 1
#  8: QN("Sz",5) => 1
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [13] ((dim=2|id=981|"S=1/2,Site,n=13") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=930|"Link,l=13") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 1
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 2
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=11|id=771|"Link,l=12") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 1
#  3: QN("Sz",-4) => 1
#  4: QN("Sz",-2) => 1
#  5: QN("Sz",0) => 2
#  6: QN("Sz",2) => 2
#  7: QN("Sz",4) => 1
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [14] ((dim=2|id=54|"S=1/2,Site,n=14") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=511|"Link,l=14") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1, (dim=11|id=930|"Link,l=13") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 1
#  3: QN("Sz",-3) => 1
#  4: QN("Sz",-1) => 2
#  5: QN("Sz",1) => 2
#  6: QN("Sz",3) => 2
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [15] ((dim=2|id=88|"S=1/2,Site,n=15") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=782|"Link,l=15") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1, (dim=11|id=511|"Link,l=14") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 1
#  3: QN("Sz",-2) => 2
#  4: QN("Sz",0) => 3
#  5: QN("Sz",2) => 2
#  6: QN("Sz",4) => 1
#  7: QN("Sz",6) => 1)
# [16] ((dim=2|id=186|"S=1/2,Site,n=16") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=11|id=393|"Link,l=16") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 3
#  5: QN("Sz",4) => 1, (dim=11|id=782|"Link,l=15") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 2
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",1) => 3
#  5: QN("Sz",3) => 1
#  6: QN("Sz",5) => 1)
# [17] ((dim=2|id=155|"S=1/2,Site,n=17") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=448|"Link,l=17") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=11|id=393|"Link,l=16") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 3
#  3: QN("Sz",0) => 3
#  4: QN("Sz",2) => 3
#  5: QN("Sz",4) => 1)
# [18] ((dim=2|id=834|"S=1/2,Site,n=18") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=680|"Link,l=18") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=448|"Link,l=17") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [19] ((dim=2|id=547|"S=1/2,Site,n=19") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=540|"Link,l=19") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=680|"Link,l=18") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [20] ((dim=2|id=309|"S=1/2,Site,n=20") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=540|"Link,l=19") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "N" => 20, "σ" => 0.002)
#  Dict("act" => MPS
# [1] ((dim=2|id=235|"S=1/2,Site,n=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=867|"Link,l=1") <In>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1)
# [2] ((dim=2|id=887|"S=1/2,Site,n=2") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=867|"Link,l=1") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=9|"Link,l=2") <In>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1)
# [3] ((dim=2|id=322|"S=1/2,Site,n=3") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=9|"Link,l=2") <Out>
#  1: QN("Sz",2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",-2) => 1, (dim=8|id=317|"Link,l=3") <In>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1)
# [4] ((dim=2|id=4|"S=1/2,Site,n=4") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=317|"Link,l=3") <Out>
#  1: QN("Sz",3) => 1
#  2: QN("Sz",1) => 3
#  3: QN("Sz",-1) => 3
#  4: QN("Sz",-3) => 1, (dim=14|id=770|"Link,l=4") <In>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1)
# [5] ((dim=2|id=620|"S=1/2,Site,n=5") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=770|"Link,l=4") <Out>
#  1: QN("Sz",4) => 1
#  2: QN("Sz",2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",-4) => 1, (dim=22|id=966|"Link,l=5") <In>
#  1: QN("Sz",5) => 1
#  2: QN("Sz",3) => 5
# ...
#  11: QN("Sz",-2) => 1
#  12: QN("Sz",0) => 2
#  13: QN("Sz",2) => 1
#  14: QN("Sz",4) => 1
#  15: QN("Sz",6) => 1
#  16: QN("Sz",8) => 1
#  17: QN("Sz",10) => 1
#  18: QN("Sz",12) => 1
#  19: QN("Sz",14) => 1
#  20: QN("Sz",16) => 1
#  21: QN("Sz",18) => 1
#  22: QN("Sz",20) => 1
#  23: QN("Sz",22) => 1)
# [38] ((dim=2|id=787|"S=1/2,Site,n=38") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=351|"Link,l=38") <Out>
#  1: QN("Sz",-22) => 1
#  2: QN("Sz",-20) => 1
#  3: QN("Sz",-18) => 1
#  4: QN("Sz",-16) => 1
#  5: QN("Sz",-14) => 1
#  6: QN("Sz",-12) => 1
#  7: QN("Sz",-10) => 1
#  8: QN("Sz",-8) => 1
#  9: QN("Sz",-6) => 1
#  10: QN("Sz",-4) => 1
#  11: QN("Sz",-2) => 1
#  12: QN("Sz",0) => 2
#  13: QN("Sz",2) => 1
#  14: QN("Sz",4) => 1
#  15: QN("Sz",6) => 1
#  16: QN("Sz",8) => 1
#  17: QN("Sz",10) => 1
#  18: QN("Sz",12) => 1
#  19: QN("Sz",14) => 1
#  20: QN("Sz",16) => 1
#  21: QN("Sz",18) => 1
#  22: QN("Sz",20) => 1
#  23: QN("Sz",22) => 1, (dim=24|id=605|"Link,l=37") <In>
#  1: QN("Sz",-21) => 1
#  2: QN("Sz",-19) => 1
#  3: QN("Sz",-17) => 1
#  4: QN("Sz",-15) => 1
#  5: QN("Sz",-13) => 1
#  6: QN("Sz",-11) => 1
#  7: QN("Sz",-9) => 1
#  8: QN("Sz",-7) => 1
#  9: QN("Sz",-5) => 1
#  10: QN("Sz",-3) => 1
#  11: QN("Sz",-1) => 2
#  12: QN("Sz",1) => 2
#  13: QN("Sz",3) => 1
#  14: QN("Sz",5) => 1
#  15: QN("Sz",7) => 1
#  16: QN("Sz",9) => 1
#  17: QN("Sz",11) => 1
#  18: QN("Sz",13) => 1
#  19: QN("Sz",15) => 1
#  20: QN("Sz",17) => 1
#  21: QN("Sz",19) => 1
#  22: QN("Sz",21) => 1)
# [39] ((dim=2|id=726|"S=1/2,Site,n=39") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=644|"Link,l=39") <Out>
#  1: QN("Sz",-21) => 1
#  2: QN("Sz",-19) => 1
#  3: QN("Sz",-17) => 1
#  4: QN("Sz",-15) => 1
#  5: QN("Sz",-13) => 1
#  6: QN("Sz",-11) => 1
#  7: QN("Sz",-9) => 1
#  8: QN("Sz",-7) => 1
#  9: QN("Sz",-5) => 1
#  10: QN("Sz",-3) => 1
#  11: QN("Sz",-1) => 2
#  12: QN("Sz",1) => 2
#  13: QN("Sz",3) => 1
#  14: QN("Sz",5) => 1
#  15: QN("Sz",7) => 1
#  16: QN("Sz",9) => 1
#  17: QN("Sz",11) => 1
#  18: QN("Sz",13) => 1
#  19: QN("Sz",15) => 1
#  20: QN("Sz",17) => 1
#  21: QN("Sz",19) => 1
#  22: QN("Sz",21) => 1, (dim=24|id=351|"Link,l=38") <In>
#  1: QN("Sz",-22) => 1
#  2: QN("Sz",-20) => 1
#  3: QN("Sz",-18) => 1
#  4: QN("Sz",-16) => 1
#  5: QN("Sz",-14) => 1
#  6: QN("Sz",-12) => 1
#  7: QN("Sz",-10) => 1
#  8: QN("Sz",-8) => 1
#  9: QN("Sz",-6) => 1
#  10: QN("Sz",-4) => 1
#  11: QN("Sz",-2) => 1
#  12: QN("Sz",0) => 2
#  13: QN("Sz",2) => 1
#  14: QN("Sz",4) => 1
#  15: QN("Sz",6) => 1
#  16: QN("Sz",8) => 1
#  17: QN("Sz",10) => 1
#  18: QN("Sz",12) => 1
#  19: QN("Sz",14) => 1
#  20: QN("Sz",16) => 1
#  21: QN("Sz",18) => 1
#  22: QN("Sz",20) => 1
#  23: QN("Sz",22) => 1)
# [40] ((dim=2|id=526|"S=1/2,Site,n=40") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=134|"Link,l=40") <Out>
#  1: QN("Sz",-20) => 1
#  2: QN("Sz",-18) => 1
#  3: QN("Sz",-16) => 1
#  4: QN("Sz",-14) => 1
#  5: QN("Sz",-12) => 1
#  6: QN("Sz",-10) => 1
#  7: QN("Sz",-8) => 1
#  8: QN("Sz",-6) => 1
#  9: QN("Sz",-4) => 1
#  10: QN("Sz",-2) => 2
#  11: QN("Sz",0) => 2
#  12: QN("Sz",2) => 2
#  13: QN("Sz",4) => 1
#  14: QN("Sz",6) => 1
#  15: QN("Sz",8) => 1
#  16: QN("Sz",10) => 1
#  17: QN("Sz",12) => 1
#  18: QN("Sz",14) => 1
#  19: QN("Sz",16) => 1
#  20: QN("Sz",18) => 1
#  21: QN("Sz",20) => 1, (dim=24|id=644|"Link,l=39") <In>
#  1: QN("Sz",-21) => 1
#  2: QN("Sz",-19) => 1
#  3: QN("Sz",-17) => 1
#  4: QN("Sz",-15) => 1
#  5: QN("Sz",-13) => 1
#  6: QN("Sz",-11) => 1
#  7: QN("Sz",-9) => 1
#  8: QN("Sz",-7) => 1
#  9: QN("Sz",-5) => 1
#  10: QN("Sz",-3) => 1
#  11: QN("Sz",-1) => 2
#  12: QN("Sz",1) => 2
#  13: QN("Sz",3) => 1
#  14: QN("Sz",5) => 1
#  15: QN("Sz",7) => 1
#  16: QN("Sz",9) => 1
#  17: QN("Sz",11) => 1
#  18: QN("Sz",13) => 1
#  19: QN("Sz",15) => 1
#  20: QN("Sz",17) => 1
#  21: QN("Sz",19) => 1
#  22: QN("Sz",21) => 1)
# [41] ((dim=2|id=863|"S=1/2,Site,n=41") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=209|"Link,l=41") <Out>
#  1: QN("Sz",-19) => 1
#  2: QN("Sz",-17) => 1
#  3: QN("Sz",-15) => 1
#  4: QN("Sz",-13) => 1
#  5: QN("Sz",-11) => 1
#  6: QN("Sz",-9) => 1
#  7: QN("Sz",-7) => 1
#  8: QN("Sz",-5) => 1
#  9: QN("Sz",-3) => 2
#  10: QN("Sz",-1) => 2
#  11: QN("Sz",1) => 2
#  12: QN("Sz",3) => 2
#  13: QN("Sz",5) => 1
#  14: QN("Sz",7) => 1
#  15: QN("Sz",9) => 1
#  16: QN("Sz",11) => 1
#  17: QN("Sz",13) => 1
#  18: QN("Sz",15) => 1
#  19: QN("Sz",17) => 1
#  20: QN("Sz",19) => 1, (dim=24|id=134|"Link,l=40") <In>
#  1: QN("Sz",-20) => 1
#  2: QN("Sz",-18) => 1
#  3: QN("Sz",-16) => 1
#  4: QN("Sz",-14) => 1
#  5: QN("Sz",-12) => 1
#  6: QN("Sz",-10) => 1
#  7: QN("Sz",-8) => 1
#  8: QN("Sz",-6) => 1
#  9: QN("Sz",-4) => 1
#  10: QN("Sz",-2) => 2
#  11: QN("Sz",0) => 2
#  12: QN("Sz",2) => 2
#  13: QN("Sz",4) => 1
#  14: QN("Sz",6) => 1
#  15: QN("Sz",8) => 1
#  16: QN("Sz",10) => 1
#  17: QN("Sz",12) => 1
#  18: QN("Sz",14) => 1
#  19: QN("Sz",16) => 1
#  20: QN("Sz",18) => 1
#  21: QN("Sz",20) => 1)
# [42] ((dim=2|id=887|"S=1/2,Site,n=42") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=567|"Link,l=42") <Out>
#  1: QN("Sz",-18) => 1
#  2: QN("Sz",-16) => 1
#  3: QN("Sz",-14) => 1
#  4: QN("Sz",-12) => 1
#  5: QN("Sz",-10) => 1
#  6: QN("Sz",-8) => 1
#  7: QN("Sz",-6) => 1
#  8: QN("Sz",-4) => 2
#  9: QN("Sz",-2) => 2
#  10: QN("Sz",0) => 2
#  11: QN("Sz",2) => 2
#  12: QN("Sz",4) => 2
#  13: QN("Sz",6) => 1
#  14: QN("Sz",8) => 1
#  15: QN("Sz",10) => 1
#  16: QN("Sz",12) => 1
#  17: QN("Sz",14) => 1
#  18: QN("Sz",16) => 1
#  19: QN("Sz",18) => 1, (dim=24|id=209|"Link,l=41") <In>
#  1: QN("Sz",-19) => 1
#  2: QN("Sz",-17) => 1
#  3: QN("Sz",-15) => 1
#  4: QN("Sz",-13) => 1
#  5: QN("Sz",-11) => 1
#  6: QN("Sz",-9) => 1
#  7: QN("Sz",-7) => 1
#  8: QN("Sz",-5) => 1
#  9: QN("Sz",-3) => 2
#  10: QN("Sz",-1) => 2
#  11: QN("Sz",1) => 2
#  12: QN("Sz",3) => 2
#  13: QN("Sz",5) => 1
#  14: QN("Sz",7) => 1
#  15: QN("Sz",9) => 1
#  16: QN("Sz",11) => 1
#  17: QN("Sz",13) => 1
#  18: QN("Sz",15) => 1
#  19: QN("Sz",17) => 1
#  20: QN("Sz",19) => 1)
# [43] ((dim=2|id=443|"S=1/2,Site,n=43") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=593|"Link,l=43") <Out>
#  1: QN("Sz",-17) => 1
#  2: QN("Sz",-15) => 1
#  3: QN("Sz",-13) => 1
#  4: QN("Sz",-11) => 1
#  5: QN("Sz",-9) => 1
#  6: QN("Sz",-7) => 1
#  7: QN("Sz",-5) => 2
#  8: QN("Sz",-3) => 2
#  9: QN("Sz",-1) => 2
#  10: QN("Sz",1) => 2
#  11: QN("Sz",3) => 2
#  12: QN("Sz",5) => 2
#  13: QN("Sz",7) => 1
#  14: QN("Sz",9) => 1
#  15: QN("Sz",11) => 1
#  16: QN("Sz",13) => 1
#  17: QN("Sz",15) => 1
#  18: QN("Sz",17) => 1, (dim=24|id=567|"Link,l=42") <In>
#  1: QN("Sz",-18) => 1
#  2: QN("Sz",-16) => 1
#  3: QN("Sz",-14) => 1
#  4: QN("Sz",-12) => 1
#  5: QN("Sz",-10) => 1
#  6: QN("Sz",-8) => 1
#  7: QN("Sz",-6) => 1
#  8: QN("Sz",-4) => 2
#  9: QN("Sz",-2) => 2
#  10: QN("Sz",0) => 2
#  11: QN("Sz",2) => 2
#  12: QN("Sz",4) => 2
#  13: QN("Sz",6) => 1
#  14: QN("Sz",8) => 1
#  15: QN("Sz",10) => 1
#  16: QN("Sz",12) => 1
#  17: QN("Sz",14) => 1
#  18: QN("Sz",16) => 1
#  19: QN("Sz",18) => 1)
# [44] ((dim=2|id=227|"S=1/2,Site,n=44") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=251|"Link,l=44") <Out>
#  1: QN("Sz",-16) => 1
#  2: QN("Sz",-14) => 1
#  3: QN("Sz",-12) => 1
#  4: QN("Sz",-10) => 1
#  5: QN("Sz",-8) => 1
#  6: QN("Sz",-6) => 2
#  7: QN("Sz",-4) => 2
#  8: QN("Sz",-2) => 2
#  9: QN("Sz",0) => 2
#  10: QN("Sz",2) => 2
#  11: QN("Sz",4) => 2
#  12: QN("Sz",6) => 2
#  13: QN("Sz",8) => 1
#  14: QN("Sz",10) => 1
#  15: QN("Sz",12) => 1
#  16: QN("Sz",14) => 1
#  17: QN("Sz",16) => 1, (dim=24|id=593|"Link,l=43") <In>
#  1: QN("Sz",-17) => 1
#  2: QN("Sz",-15) => 1
#  3: QN("Sz",-13) => 1
#  4: QN("Sz",-11) => 1
#  5: QN("Sz",-9) => 1
#  6: QN("Sz",-7) => 1
#  7: QN("Sz",-5) => 2
#  8: QN("Sz",-3) => 2
#  9: QN("Sz",-1) => 2
#  10: QN("Sz",1) => 2
#  11: QN("Sz",3) => 2
#  12: QN("Sz",5) => 2
#  13: QN("Sz",7) => 1
#  14: QN("Sz",9) => 1
#  15: QN("Sz",11) => 1
#  16: QN("Sz",13) => 1
#  17: QN("Sz",15) => 1
#  18: QN("Sz",17) => 1)
# [45] ((dim=2|id=363|"S=1/2,Site,n=45") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=665|"Link,l=45") <Out>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 2
#  6: QN("Sz",-5) => 2
#  7: QN("Sz",-3) => 2
#  8: QN("Sz",-1) => 2
#  9: QN("Sz",1) => 2
#  10: QN("Sz",3) => 2
#  11: QN("Sz",5) => 2
#  12: QN("Sz",7) => 2
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1, (dim=24|id=251|"Link,l=44") <In>
#  1: QN("Sz",-16) => 1
#  2: QN("Sz",-14) => 1
#  3: QN("Sz",-12) => 1
#  4: QN("Sz",-10) => 1
#  5: QN("Sz",-8) => 1
#  6: QN("Sz",-6) => 2
#  7: QN("Sz",-4) => 2
#  8: QN("Sz",-2) => 2
#  9: QN("Sz",0) => 2
#  10: QN("Sz",2) => 2
#  11: QN("Sz",4) => 2
#  12: QN("Sz",6) => 2
#  13: QN("Sz",8) => 1
#  14: QN("Sz",10) => 1
#  15: QN("Sz",12) => 1
#  16: QN("Sz",14) => 1
#  17: QN("Sz",16) => 1)
# [46] ((dim=2|id=360|"S=1/2,Site,n=46") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=66|"Link,l=46") <Out>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 2
#  6: QN("Sz",-4) => 2
#  7: QN("Sz",-2) => 2
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 2
#  11: QN("Sz",6) => 2
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1, (dim=24|id=665|"Link,l=45") <In>
#  1: QN("Sz",-15) => 1
#  2: QN("Sz",-13) => 1
#  3: QN("Sz",-11) => 1
#  4: QN("Sz",-9) => 1
#  5: QN("Sz",-7) => 2
#  6: QN("Sz",-5) => 2
#  7: QN("Sz",-3) => 2
#  8: QN("Sz",-1) => 2
#  9: QN("Sz",1) => 2
#  10: QN("Sz",3) => 2
#  11: QN("Sz",5) => 2
#  12: QN("Sz",7) => 2
#  13: QN("Sz",9) => 1
#  14: QN("Sz",11) => 1
#  15: QN("Sz",13) => 1
#  16: QN("Sz",15) => 1)
# [47] ((dim=2|id=62|"S=1/2,Site,n=47") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=695|"Link,l=47") <Out>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 2
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 4
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 3
#  10: QN("Sz",5) => 2
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1, (dim=24|id=66|"Link,l=46") <In>
#  1: QN("Sz",-14) => 1
#  2: QN("Sz",-12) => 1
#  3: QN("Sz",-10) => 1
#  4: QN("Sz",-8) => 1
#  5: QN("Sz",-6) => 2
#  6: QN("Sz",-4) => 2
#  7: QN("Sz",-2) => 2
#  8: QN("Sz",0) => 3
#  9: QN("Sz",2) => 3
#  10: QN("Sz",4) => 2
#  11: QN("Sz",6) => 2
#  12: QN("Sz",8) => 1
#  13: QN("Sz",10) => 1
#  14: QN("Sz",12) => 1
#  15: QN("Sz",14) => 1)
# [48] ((dim=2|id=452|"S=1/2,Site,n=48") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=5|"Link,l=48") <Out>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 2
#  5: QN("Sz",-4) => 3
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 3
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1, (dim=24|id=695|"Link,l=47") <In>
#  1: QN("Sz",-13) => 1
#  2: QN("Sz",-11) => 1
#  3: QN("Sz",-9) => 1
#  4: QN("Sz",-7) => 1
#  5: QN("Sz",-5) => 2
#  6: QN("Sz",-3) => 2
#  7: QN("Sz",-1) => 4
#  8: QN("Sz",1) => 3
#  9: QN("Sz",3) => 3
#  10: QN("Sz",5) => 2
#  11: QN("Sz",7) => 1
#  12: QN("Sz",9) => 1
#  13: QN("Sz",11) => 1
#  14: QN("Sz",13) => 1)
# [49] ((dim=2|id=534|"S=1/2,Site,n=49") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=165|"Link,l=49") <Out>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 3
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 3
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1, (dim=24|id=5|"Link,l=48") <In>
#  1: QN("Sz",-12) => 1
#  2: QN("Sz",-10) => 1
#  3: QN("Sz",-8) => 1
#  4: QN("Sz",-6) => 2
#  5: QN("Sz",-4) => 3
#  6: QN("Sz",-2) => 3
#  7: QN("Sz",0) => 3
#  8: QN("Sz",2) => 3
#  9: QN("Sz",4) => 3
#  10: QN("Sz",6) => 1
#  11: QN("Sz",8) => 1
#  12: QN("Sz",10) => 1
#  13: QN("Sz",12) => 1)
# [50] ((dim=2|id=733|"S=1/2,Site,n=50") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=604|"Link,l=50") <Out>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 2
#  4: QN("Sz",-4) => 3
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 4
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 3
#  9: QN("Sz",6) => 2
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1, (dim=24|id=165|"Link,l=49") <In>
#  1: QN("Sz",-11) => 1
#  2: QN("Sz",-9) => 1
#  3: QN("Sz",-7) => 1
#  4: QN("Sz",-5) => 3
#  5: QN("Sz",-3) => 3
#  6: QN("Sz",-1) => 3
#  7: QN("Sz",1) => 3
#  8: QN("Sz",3) => 3
#  9: QN("Sz",5) => 3
#  10: QN("Sz",7) => 1
#  11: QN("Sz",9) => 1
#  12: QN("Sz",11) => 1)
# [51] ((dim=2|id=642|"S=1/2,Site,n=51") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=385|"Link,l=51") <Out>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 3
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 4
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 3
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1, (dim=24|id=604|"Link,l=50") <In>
#  1: QN("Sz",-10) => 1
#  2: QN("Sz",-8) => 1
#  3: QN("Sz",-6) => 2
#  4: QN("Sz",-4) => 3
#  5: QN("Sz",-2) => 3
#  6: QN("Sz",0) => 4
#  7: QN("Sz",2) => 3
#  8: QN("Sz",4) => 3
#  9: QN("Sz",6) => 2
#  10: QN("Sz",8) => 1
#  11: QN("Sz",10) => 1)
# [52] ((dim=2|id=552|"S=1/2,Site,n=52") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=124|"Link,l=52") <Out>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 2
#  3: QN("Sz",-4) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1, (dim=24|id=385|"Link,l=51") <In>
#  1: QN("Sz",-9) => 1
#  2: QN("Sz",-7) => 1
#  3: QN("Sz",-5) => 3
#  4: QN("Sz",-3) => 3
#  5: QN("Sz",-1) => 4
#  6: QN("Sz",1) => 4
#  7: QN("Sz",3) => 3
#  8: QN("Sz",5) => 3
#  9: QN("Sz",7) => 1
#  10: QN("Sz",9) => 1)
# [53] ((dim=2|id=517|"S=1/2,Site,n=53") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=249|"Link,l=53") <Out>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 5
#  4: QN("Sz",-1) => 5
#  5: QN("Sz",1) => 5
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1, (dim=24|id=124|"Link,l=52") <In>
#  1: QN("Sz",-8) => 1
#  2: QN("Sz",-6) => 2
#  3: QN("Sz",-4) => 4
#  4: QN("Sz",-2) => 4
#  5: QN("Sz",0) => 4
#  6: QN("Sz",2) => 4
#  7: QN("Sz",4) => 3
#  8: QN("Sz",6) => 1
#  9: QN("Sz",8) => 1)
# [54] ((dim=2|id=497|"S=1/2,Site,n=54") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=24|id=250|"Link,l=54") <Out>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 4
#  3: QN("Sz",-2) => 5
#  4: QN("Sz",0) => 5
#  5: QN("Sz",2) => 5
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1, (dim=24|id=249|"Link,l=53") <In>
#  1: QN("Sz",-7) => 1
#  2: QN("Sz",-5) => 2
#  3: QN("Sz",-3) => 5
#  4: QN("Sz",-1) => 5
#  5: QN("Sz",1) => 5
#  6: QN("Sz",3) => 4
#  7: QN("Sz",5) => 1
#  8: QN("Sz",7) => 1)
# [55] ((dim=2|id=309|"S=1/2,Site,n=55") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=22|id=90|"Link,l=55") <Out>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1, (dim=24|id=250|"Link,l=54") <In>
#  1: QN("Sz",-6) => 1
#  2: QN("Sz",-4) => 4
#  3: QN("Sz",-2) => 5
#  4: QN("Sz",0) => 5
#  5: QN("Sz",2) => 5
#  6: QN("Sz",4) => 3
#  7: QN("Sz",6) => 1)
# [56] ((dim=2|id=424|"S=1/2,Site,n=56") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=14|id=446|"Link,l=56") <Out>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1, (dim=22|id=90|"Link,l=55") <In>
#  1: QN("Sz",-5) => 1
#  2: QN("Sz",-3) => 5
#  3: QN("Sz",-1) => 5
#  4: QN("Sz",1) => 5
#  5: QN("Sz",3) => 5
#  6: QN("Sz",5) => 1)
# [57] ((dim=2|id=367|"S=1/2,Site,n=57") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=8|id=417|"Link,l=57") <Out>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1, (dim=14|id=446|"Link,l=56") <In>
#  1: QN("Sz",-4) => 1
#  2: QN("Sz",-2) => 4
#  3: QN("Sz",0) => 4
#  4: QN("Sz",2) => 4
#  5: QN("Sz",4) => 1)
# [58] ((dim=2|id=727|"S=1/2,Site,n=58") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=4|id=244|"Link,l=58") <Out>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1, (dim=8|id=417|"Link,l=57") <In>
#  1: QN("Sz",-3) => 1
#  2: QN("Sz",-1) => 3
#  3: QN("Sz",1) => 3
#  4: QN("Sz",3) => 1)
# [59] ((dim=2|id=839|"S=1/2,Site,n=59") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=164|"Link,l=59") <Out>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1, (dim=4|id=244|"Link,l=58") <In>
#  1: QN("Sz",-2) => 1
#  2: QN("Sz",0) => 2
#  3: QN("Sz",2) => 1)
# [60] ((dim=2|id=596|"S=1/2,Site,n=60") <Out>
#  1: QN("Sz",1) => 1
#  2: QN("Sz",-1) => 1, (dim=2|id=164|"Link,l=59") <In>
#  1: QN("Sz",-1) => 1
#  2: QN("Sz",1) => 1)
# , "N" => 60, "σ" => 0.002)

# %%
function fidelity_between_schmidt_spectrums(mps1, mps2)
    overlap = inner(mps1, mps2)
    fidelity = abs(overlap)^2
    return fidelity
end
# Out:
# fidelity_between_schmidt_spectrums (generic function with 1 method)

# %%
using Plots

function plot_fidelity_vs_N(results)
    unique_sigmas = sort(unique([d["σ"] for d in results]))
    
    p = plot(
        title = "Fidelity of approximated state vs System Size (N)",
        xlabel = "System Size (N)",
        ylabel = "Fidelity ",
        legend = :topleft,
        grid = true,
        bg_legend = :transparent,
    )
    
    for σ in unique_sigmas
        sigma_data = filter(d -> d["σ"] == σ, results)
    
        sort!(sigma_data, by = d -> d["N"])
        
        x_vals = [d["N"] for d in sigma_data]
        apx_vals = [d["apx"] for d in sigma_data]
        act_vals = [d["act"] for d in sigma_data]

        overlap = []
        for i in 1:length(apx_vals)
            push!(overlap, fidelity_between_schmidt_spectrums(apx_vals[i], act_vals[i]))
        end
        
        plot!(p, x_vals, overlap, 
            label = "σ = $σ", 
            marker = :circle, 
            linewidth = 2,
            alpha=0.7
        )
    end
    
    return p
end

plot_overap_vs_N(appx_result)
